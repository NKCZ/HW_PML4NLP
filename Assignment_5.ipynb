# %% [markdown]
# <img src="https://communications.univie.ac.at/fileadmin/_processed_/csm_Uni_Logo_2016_2f47aacf37.jpg"
#      alt="Logo Universität Wien"
#      width="200"/>
#
# # Practical Machine Learning for Natural Language Processing - 2023 SS
#
# ### Assigment 1 - Python for Poets
#
# This assigment is an adaptation for Python of the original exercise ["Unix for Poets"](https://www.cs.upc.edu/~padro/Unixforpoets.pdf)

# %% [markdown]
# ***

# %% [markdown]
# ### Loading the document

# %%
#with open("../../Data/txt/nyt_200811.txt", "r") as f:
with open(r"nyt_200811.txt", "r") as f:
    text = f.read()

print(text[0:500])
# Out:
# KBR said Friday the global economic downturn so far has
# had
# little effect on its business but warned some projects on its books
# could be in jeopardy if the headwinds persist into next year.
#
# "With the economic outlook remaining uncertain, it is possible
# that
# customers may cancel or delay projects that are under way," said
# William
# Utt, chief executive of the Houston-based engineering and
# construction
# giant and government contractor.
#
# He did not predict how much of the company's $15.3billion in
# fu

# %% [markdown]
# ***

# %% [markdown]
# ### You will solve the following exercises using **Pure Python** (only package "string" and "re" are allowed).
# 1. Count words in a text
# 2. Sort a list of words in various ways
#    • ascii order
#    • "rhyming" order
# 3. Extract useful info for a dictionary
# 4. Compute ngram statistics
# 5. Make a Concordance

# %% [markdown]
# ***

# %% [markdown]
# #### 0. Import "string"

# %%
import string

# %% [markdown]
# #### 1. Count words in a text
#
# a. Output a list of words in the file along with their frequency counts (ignoring case).
# a. Count how many unique words there are (ignoring case).
# c. Check how common are all different sequences of vowels (e.g. the sequences "ieu" or just "e" in "lieutenant")?

# %%
# a)
text_lower = text.lower()
text_list = [w.strip(string.punctuation) for w in text_lower.split()]
text_set = set(text_list) # only unique values
text_set.remove('')
freq_list = [text_list.count(x) for x in text_set]

freq = {word:w_freq for word, w_freq in zip(text_set, freq_list)}

# %%
freq
# Out:
# {'gabbi': 1,
#  'yo-yo': 1,
#  'solidified': 5,
#  'five-part': 1,
#  'two-act': 1,
#  'dura': 1,
#  'mem': 1,
#  'obligated': 3,
#  'sandwiched': 1,
#  'ground-breaking': 1,
#  'picky': 1,
#  'suffolk': 6,
#  '3,832': 1,
#  'valueless': 1,
#  'subordinates': 3,
#  'willie': 4,
#  'hear': 49,
#  'haut': 1,
#  '1,350': 2,
#  't-shirt': 10,
#  'arzt': 1,
#  'peninsula': 9,
#  'mockingbird': 2,
#  'establishing': 3,
#  'sentiments': 3,
#  'merchant': 3,
#  'vote--all': 1,
#  'funded': 2,
#  'statisticians': 2,
#  'aston': 1,
#  're-use': 1,
#  'equivalence': 1,
#  'intensive': 8,
#  'relied': 6,
#  'rzasa': 1,
#  'capitals': 3,
#  'dayspring': 1,
#  'linus': 1,
#  'disseminated': 1,
#  'loyalists--had': 1,
#  'circuit': 13,
#  'variously': 1,
#  'sabato': 3,
#  'donora': 17,
#  'healed': 2,
#  'bankers': 16,
#  'vittorio': 1,
#  'x-chromosome': 1,
#  'delude': 1,
#  'spots': 14,
#  'dixon': 1,
#  'voter': 78,
#  'buts': 2,
#  'joking': 3,
#  'guaranteeing': 3,
#  'detached': 6,
#  'repledge': 1,
#  '1931': 1,
#  'hopped': 1,
#  'tones': 3,
#  'since': 413,
#  '19th-century': 5,
#  "wyoming's": 2,
#  'chain': 15,
#  'infiltrate': 1,
#  'scrap': 5,
#  'truancy': 1,
#  '190': 3,
#  "miller's": 1,
#  'felon': 1,
#  '1:46': 1,
#  'pediatric': 2,
#  'broccoli': 16,
#  'homayun': 2,
#  'hazard': 4,
#  'di': 1,
#  'jacoby': 2,
#  'homogeneity': 1,
#  'rovian': 1,
#  'ba': 1,
#  'transforming': 4,
#  'promise': 27,
#  'mug': 2,
#  'extravaganza': 1,
#  'jingoism': 1,
#  'amc': 1,
#  'pizza': 5,
#  'friedman': 7,
#  'palinaspresident.com': 1,
#  'milky': 1,
#  'controversial': 13,
#  'reigned': 1,
#  'inaction': 2,
#  'looting': 1,
#  "bahlul's": 1,
#  'soul-searching': 1,
#  'lie-detector': 1,
#  'intermittent': 1,
#  '79': 5,
#  'deal-making': 5,
#  'mate': 40,
#  'assertive': 1,
#  'balky': 1,
#  'ellenton': 2,
#  'vq': 2,
#  "hadn't": 25,
#  'intentions': 8,
#  'nicolaus': 5,
#  'tarpaulins': 1,
#  'kirk': 2,
#  "abdullah's": 1,
#  'anatomically': 1,
#  'freewheeling': 2,
#  '1/3': 9,
#  'what-for': 1,
#  'vnesheconombank': 2,
#  'measured': 5,
#  'fretting': 1,
#  'terron': 3,
#  'poorest': 2,
#  "bradley's": 3,
#  'jacqueline': 2,
#  'boothbay': 6,
#  'counterpoint': 4,
#  'hard-fought': 4,
#  'baldly': 1,
#  'sad': 11,
#  'degrees': 21,
#  'athens': 29,
#  '5-year': 1,
#  '3.3': 5,
#  'renewal': 1,
#  "news's": 1,
#  'chaz': 1,
#  'winningest': 2,
#  'notebook': 4,
#  'jewish': 23,
#  'grills': 3,
#  'long-lost': 1,
#  'campaigned': 14,
#  'tougher': 7,
#  'marine': 31,
#  'gunnlaugsson': 3,
#  'caskets': 1,
#  'wended': 1,
#  'auction': 12,
#  'loan': 64,
#  'keflezighi': 1,
#  'syringe': 2,
#  'minus-8': 1,
#  'white-majority': 1,
#  'ac': 1,
#  'secretariat': 2,
#  'washing': 8,
#  'jake': 10,
#  'proceeded': 2,
#  'ones': 43,
#  'youtube': 20,
#  'mst': 1,
#  'blume': 1,
#  'tag': 6,
#  'renzo': 1,
#  'browses': 2,
#  'disaster-filled': 1,
#  '29-19': 1,
#  'tension': 6,
#  "wallace's": 1,
#  'mel': 5,
#  'georgetown': 6,
#  'chris': 48,
#  'essentially': 13,
#  'clam': 1,
#  'embarrassed': 7,
#  'slap-stick': 1,
#  'careers': 6,
#  'financially': 8,
#  'ron': 9,
#  'therese': 2,
#  'solrun': 2,
#  'stressed': 5,
#  'fallout': 7,
#  'pylon': 1,
#  'nineteenth': 1,
#  '16,460': 1,
#  'titlists': 1,
#  'strike': 24,
#  'damnation': 1,
#  'powertrain': 1,
#  'combo': 1,
#  'apolitical': 2,
#  'requested': 8,
#  'equipment': 20,
#  'licenses': 10,
#  'inventive': 1,
#  'simulated': 1,
#  'wms': 3,
#  'station': 25,
#  'confidential': 8,
#  'melbourne': 1,
#  'yelled': 1,
#  'conservative': 80,
#  'teixeira': 8,
#  'addai': 2,
#  'hal': 2,
#  'enthusiastically': 1,
#  'jitters': 2,
#  'commerce': 17,
#  '08': 2,
#  'timeless': 1,
#  'sandy': 5,
#  'working': 129,
#  '3-1': 6,
#  'skillet': 4,
#  "club's": 4,
#  "farm's": 3,
#  'logical': 7,
#  'amendments': 8,
#  'lessen': 1,
#  'guidance': 6,
#  'suburb': 12,
#  'porkfest': 1,
#  'schwalbe': 7,
#  'chip': 4,
#  'slowly': 11,
#  'inner-city': 3,
#  'avante-gardist': 1,
#  'dwindling': 6,
#  'swiftly': 4,
#  'levitating': 1,
#  'na': 7,
#  'preventive': 2,
#  'curve': 2,
#  'tintin': 4,
#  'emphasize': 2,
#  'satsuki': 1,
#  'unwed': 1,
#  'respective': 2,
#  'carved': 8,
#  'clear': 96,
#  'scrounging': 1,
#  'lasted': 8,
#  'git-go': 1,
#  'multi-pronged': 1,
#  'precursor': 1,
#  'carcieri': 1,
#  'grondona': 6,
#  'goodwill': 1,
#  'guideposts': 1,
#  'aura': 1,
#  'contention': 6,
#  'insular': 3,
#  'stipend': 1,
#  'ages': 19,
#  'shakily': 1,
#  'intersect': 2,
#  'double-cover': 1,
#  'knownshon': 1,
#  'devised': 2,
#  'romantic': 16,
#  'moseley': 1,
#  'incidental': 1,
#  'interim': 5,
#  'quarry': 2,
#  'ridicule': 1,
#  'mid-50s': 1,
#  'attends': 2,
#  'bernards': 4,
#  '20.7': 1,
#  '23.9': 2,
#  'tit-for-tat': 1,
#  'begin': 63,
#  'dynamics': 3,
#  'reorganize': 1,
#  'discovers': 2,
#  'lom': 1,
#  'strained': 3,
#  'prompt': 8,
#  'pregnancy': 18,
#  'president': 554,
#  'envisaged': 1,
#  'unchanged': 3,
#  'herd': 1,
#  'election': 518,
#  'someday': 3,
#  'spouting': 1,
#  'southeast': 14,
#  'all-torain': 1,
#  'leyritz': 40,
#  'catalyzing': 1,
#  'islamabad': 5,
#  'rhetoric': 11,
#  'hollers': 1,
#  'house': 286,
#  'eni': 1,
#  'victorian': 2,
#  'plugs': 1,
#  'bellsouth.net': 2,
#  'wildest': 4,
#  'horrendous': 2,
#  'responds': 1,
#  'apathy': 2,
#  'festive': 1,
#  'paths': 5,
#  'outpouring': 3,
#  'bruise': 3,
#  'accompli': 1,
#  'loyal': 11,
#  'swiped': 1,
#  'calvary': 6,
#  'raises': 13,
#  'leaves': 25,
#  "region's": 2,
#  "eli's": 7,
#  'chrissy': 1,
#  'intrusion': 1,
#  'ferrari': 12,
#  'pirouetted': 1,
#  'consensus': 11,
#  'engravings': 1,
#  'author': 43,
#  'application': 14,
#  'second-guess': 2,
#  'surplus': 5,
#  'tornados': 1,
#  'foot-pounds': 9,
#  'sips': 1,
#  'objectives': 1,
#  '1972-80': 2,
#  'three-quarters': 6,
#  'archaeology': 1,
#  'broadway-short-run': 1,
#  'menacingly': 2,
#  'pitchers': 10,
#  'lacking': 3,
#  'teenage': 10,
#  'unstoppable': 2,
#  '18-month': 2,
#  'firefighter': 1,
#  'night': 275,
#  'britain': 30,
#  'sparky': 1,
#  'tape-delay': 1,
#  'gathering': 17,
#  'marlene': 4,
#  '3.5': 6,
#  'pencils': 2,
#  'products': 47,
#  'hugger': 1,
#  'simmer': 3,
#  'kubiak': 2,
#  'halving': 1,
#  'critics': 38,
#  'composer': 6,
#  'limelight': 3,
#  'whose': 151,
#  'gender-wise': 1,
#  'michelle': 15,
#  'accumulations': 1,
#  'nailed': 2,
#  'marshawn': 2,
#  'hypnotic': 2,
#  'fiasco': 2,
#  'hungering': 1,
#  'congregational': 1,
#  'castro': 3,
#  'pre-anderson': 1,
#  'c.b': 1,
#  'culling': 1,
#  'linguist': 1,
#  'streak': 24,
#  'exclusive': 7,
#  'graduated': 13,
#  'shalom': 3,
#  'unreleased': 2,
#  'crosses': 3,
#  'transfer': 23,
#  'accolade': 1,
#  'appearances': 21,
#  'bleier': 1,
#  'dunked': 1,
#  'louisiana': 14,
#  'four-letter': 3,
#  'resorts': 6,
#  'creeping': 3,
#  'paring': 2,
#  "landsbanki's": 1,
#  'fascination': 2,
#  'paused': 5,
#  'vocabulary': 2,
#  'cliches': 3,
#  'flagship': 1,
#  'celebrated': 14,
#  'build-out': 1,
#  "oed's": 1,
#  '28-yard': 2,
#  'peaceniks': 1,
#  'kaplan': 5,
#  'aggression': 1,
#  'diminished': 10,
#  'brook': 16,
#  '59-year-old': 2,
#  'manhattan': 49,
#  'doings': 1,
#  'nonvoters': 2,
#  '60s-style': 1,
#  'exceedingly': 3,
#  'depositors': 6,
#  'laissez-faire': 1,
#  'flatly': 1,
#  'committed': 31,
#  'bailed': 1,
#  'hyperbole': 5,
#  'maupaneng': 1,
#  "majority's": 1,
#  'describing': 6,
#  'wiping': 1,
#  'stoic': 4,
#  'marching': 3,
#  'hollywood-based': 1,
#  'purely': 6,
#  'cardiorespiratory': 1,
#  'shootouts': 1,
#  'self-respect': 1,
#  'injured': 31,
#  'didnt': 1,
#  'moultrians': 1,
#  'peels': 3,
#  'rosado': 1,
#  'sumptuous': 1,
#  '1856': 1,
#  'golden-tongued': 1,
#  'mortgage-related': 1,
#  'insistent': 1,
#  'camby': 3,
#  'capturing': 4,
#  'reptile': 2,
#  'fund-raising': 1,
#  'slide': 7,
#  'arguments': 16,
#  'friendless': 1,
#  'starts': 26,
#  'inhabitants': 1,
#  'six-cylinder': 1,
#  'forwards': 2,
#  'foxnews.com': 1,
#  'cypress': 5,
#  'city-run': 2,
#  'thriller': 5,
#  'bolshevik': 1,
#  'shag': 1,
#  'wrestled': 2,
#  'eby': 1,
#  'ducasse': 1,
#  'despite': 104,
#  'collecting': 3,
#  'commissars': 1,
#  '45-yarders': 1,
#  'gunpoint': 1,
#  'aware': 23,
#  'jerramy': 2,
#  'pc': 9,
#  'minotaur': 1,
#  'geniality': 1,
#  'struggled': 16,
#  'eases': 2,
#  'belizaire': 2,
#  'disagreements': 4,
#  'identified': 33,
#  'judi': 1,
#  'castor': 1,
#  'goateed': 1,
#  "alicea's": 1,
#  'pointlessly': 1,
#  'converge': 1,
#  'secondary': 22,
#  'prevails': 5,
#  'avoid': 36,
#  'comptroller': 3,
#  'lovers': 6,
#  'distributes': 2,
#  'inconsistencies': 1,
#  "l'ennemi": 1,
#  'staffers': 4,
#  '1-yard': 7,
#  'sexually': 3,
#  "y'all": 2,
#  'overworked': 1,
#  "machen's": 1,
#  'haden': 5,
#  'egyptian': 5,
#  '27-inch': 1,
#  'disneyworld.com': 1,
#  'scar': 1,
#  'hyperdiscreet': 1,
#  'relayed': 2,
#  'ratcheted': 1,
#  "bryant's": 5,
#  'nouri': 1,
#  'originally': 12,
#  'unfettered': 4,
#  'well-worn': 1,
#  'incisive': 4,
#  'did': 503,
#  'wraparound': 1,
#  'toyo': 1,
#  'combined': 26,
#  'northbound': 1,
#  'clemson27bc21': 1,
#  'daffodils': 3,
#  'injecting': 1,
#  'vancouver': 4,
#  'qualified': 9,
#  "epa's": 1,
#  'topsy-turvy': 3,
#  'reveals': 3,
#  'santi': 1,
#  'archeological': 4,
#  'marbleized': 1,
#  '1,900-person': 1,
#  'occasionally': 15,
#  'gastrotypographicalassemblage': 1,
#  'gmc': 2,
#  'exact': 4,
#  'charitable': 4,
#  'alfonse': 1,
#  'majors': 7,
#  'assessed': 3,
#  'actory': 1,
#  "word's": 1,
#  'disappeared': 7,
#  'interruptions': 1,
#  'hire': 15,
#  'geography': 3,
#  'strauss-kahn': 2,
#  'ex-ram': 1,
#  'curved': 2,
#  'vinny': 12,
#  'frankel': 1,
#  'pietersburg': 1,
#  'duchess': 1,
#  'masterpiece': 1,
#  'mechanization': 1,
#  'differentiate': 1,
#  'consulting': 11,
#  'diego': 23,
#  '1965': 6,
#  'over': 691,
#  'insurmountable': 3,
#  'incarnate': 1,
#  'www.johnmccain.com': 1,
#  '2001': 38,
#  '1-800-nytimes': 2,
#  "radio's": 1,
#  'dim': 2,
#  'broad': 22,
#  "republican's": 1,
#  'dynamo': 2,
#  'sins': 1,
#  'surround': 2,
#  'renewals': 1,
#  'spaced': 1,
#  'suited': 4,
#  'krista': 1,
#  'broadcast': 33,
#  'dimmock': 1,
#  'positive': 27,
#  'timing': 19,
#  'pissarro': 1,
#  'wilfert': 1,
#  'futile': 3,
#  'fluently': 1,
#  'h.w': 6,
#  'hillsides': 3,
#  'long-lived': 1,
#  'sangria': 1,
#  'stiffer': 2,
#  'fallen': 23,
#  'fuse': 1,
#  "wendy's": 1,
#  'filmed': 6,
#  'purchases': 14,
#  'dowdye': 1,
#  'noticeable': 3,
#  '373': 1,
#  'mugged': 1,
#  'quandary': 3,
#  'lake': 17,
#  'ketchup': 3,
#  "romero's": 1,
#  'signaling': 7,
#  'gators': 38,
#  'bate': 5,
#  'tug': 3,
#  'oilandgas': 2,
#  'bergen': 2,
#  'ills': 1,
#  'marketable': 1,
#  'choosing': 14,
#  'deadlock': 2,
#  'watchword': 1,
#  'maneuverings': 1,
#  'committees': 9,
#  '7-yard': 1,
#  'mountains': 13,
#  'touraine': 1,
#  'tepid': 1,
#  "peterborough's": 1,
#  'https://www.dtv2009.gov': 1,
#  'hayek': 1,
#  'revelatory': 2,
#  'palestinians': 7,
#  'arnaldur': 1,
#  'organic': 13,
#  '313.222.2533': 2,
#  'installment': 5,
#  'forum': 14,
#  'ricocheted': 4,
#  'invariably': 3,
#  'jeter': 2,
#  '6-9': 1,
#  'poet': 7,
#  'airing': 13,
#  'rampaging': 1,
#  'amp;lt;/td&gt;&amp;lt;/tr&gt;&amp;lt;tr&gt;&amp;lt;td': 1,
#  'dicier': 1,
#  'wilner': 4,
#  'alfredsson': 5,
#  'compromised': 2,
#  'garnered': 2,
#  'porcelain': 1,
#  'angrily': 3,
#  'anti-iraq-war': 1,
#  'sweeney': 2,
#  'grumman': 1,
#  'bled': 2,
#  'take-no-prisoners': 1,
#  'informs': 3,
#  'wild"-ization': 1,
#  'commissioners': 2,
#  'unanimously': 2,
#  'mum': 1,
#  'unto': 1,
#  'audio': 7,
#  'bakery': 2,
#  'torn-paper': 2,
#  '101st': 1,
#  'outlook': 19,
#  '5-billion': 1,
#  'unsealed': 1,
#  'liguori': 1,
#  'vip': 4,
#  'coerce': 2,
#  'wizard': 1,
#  'gasket': 1,
#  'nobel': 4,
#  'strengthened': 1,
#  'cross-country': 3,
#  'open-ended': 1,
#  'injury-saddled': 1,
#  'anderman@globe.com': 1,
#  'false': 10,
#  'post-retirement': 1,
#  'mathematics': 1,
#  'gallon': 9,
#  'bleary': 1,
#  'epic': 4,
#  'begala': 1,
#  'rendered': 6,
#  'tails-you-lose': 1,
#  'hispanic': 28,
#  'spoiled': 1,
#  'throat': 3,
#  'lap': 2,
#  'half-sister': 5,
#  'immersed': 4,
#  'gated': 1,
#  'insanity': 1,
#  'moralistic': 1,
#  'shays': 2,
#  'par': 2,
#  'beau': 1,
#  'muhammed': 1,
#  'aesthetics': 1,
#  'goldeneye': 1,
#  'spinal': 1,
#  'kingsley': 1,
#  'comerica': 1,
#  'guilt-ridden': 1,
#  'pruitt-igoe': 1,
#  'mcclellan': 1,
#  'witwatersrand': 2,
#  'monopoly': 10,
#  'floor': 68,
#  'toxicology': 1,
#  '80-year-old': 1,
#  'ulianov': 1,
#  'certified': 5,
#  'bruce': 15,
#  'monaca': 1,
#  'lucero': 1,
#  'pathologically': 1,
#  'flat': 18,
#  'closest': 11,
#  'esptein': 1,
#  'garza': 4,
#  '32': 29,
#  'barrow': 18,
#  'finest': 4,
#  'glimpse': 1,
#  'forni': 1,
#  "minnie's": 1,
#  "o'toole": 1,
#  'kang': 1,
#  'attest': 2,
#  'based': 108,
#  'satirical': 1,
#  'rituals': 1,
#  'degree': 28,
#  'cemented': 4,
#  'after-nba': 1,
#  'rack': 4,
#  'bursting': 3,
#  'harbour': 2,
#  'cbancroftsptimes.com': 1,
#  'declared': 28,
#  'unheeded': 2,
#  'contradicted': 1,
#  'volition': 1,
#  'edegganssptimes.com': 1,
#  'institution': 16,
#  'ghanem': 1,
#  'deregulatory': 1,
#  'eds': 3,
#  'lopsided': 6,
#  'sabeans': 1,
#  'cellpadding"0"&gt;&amp;lt;tr&gt;&amp;lt;td&gt;lightning': 1,
#  'joke': 10,
#  'motels': 1,
#  'deng-ee': 1,
#  'ebola': 1,
#  'waiters': 4,
#  'preamble': 1,
#  'bulgarian': 2,
#  'seeks': 8,
#  'trivia': 5,
#  '303-954-1668': 1,
#  'aubrey': 1,
#  'reins': 4,
#  'high-gloss': 1,
#  '240': 1,
#  'cantillation': 1,
#  'bestseller': 1,
#  "logan's": 2,
#  'contribution': 12,
#  'genuinely': 6,
#  'plywood': 2,
#  'um': 2,
#  'wily': 3,
#  'uptick': 3,
#  'v.s': 1,
#  'peaked': 6,
#  'plain-spoken': 1,
#  'lets': 4,
#  'medley': 1,
#  'winking': 1,
#  'aggregate': 2,
#  'anchor': 25,
#  'frightened': 5,
#  'irv': 1,
#  'benchmark': 9,
#  'hepburn': 2,
#  'assassin': 2,
#  'reilly': 6,
#  'capping': 2,
#  'chalked': 3,
#  'blankly': 1,
#  'kayakers': 2,
#  'kiley': 1,
#  'eyman': 1,
#  'stepping': 6,
#  'reverse': 11,
#  'caesar': 4,
#  'endorsements': 3,
#  'sideburns': 1,
#  'baptist': 14,
#  '2.6-million': 1,
#  'rocks': 5,
#  'slayage': 2,
#  'geraldine': 1,
#  'listen': 14,
#  'continent': 10,
#  'venerable': 3,
#  'redistributive': 1,
#  'misdemeanor': 1,
#  'interviewer': 2,
#  'briton': 1,
#  'essex': 3,
#  'adjusted': 10,
#  "prosecutor's": 2,
#  'politically': 28,
#  '1946': 4,
#  'dive': 7,
#  "tribe's": 1,
#  'comet': 1,
#  "godard's": 1,
#  'onetime': 2,
#  'head': 106,
#  "president's": 6,
#  'folded': 1,
#  'wavy': 1,
#  'patricia': 7,
#  'lesson': 13,
#  'abstain': 1,
#  'mexican': 9,
#  'flinch': 2,
#  'mothership': 2,
#  'initiated': 2,
#  'tides': 3,
#  'traveling': 22,
#  '52-yard': 3,
#  "sr.'s": 2,
#  'orwell': 1,
#  'suede': 4,
#  'goaliesottawa': 1,
#  'ajar': 1,
#  'refunds': 1,
#  'germans': 4,
#  'unofficial': 5,
#  'modes': 2,
#  'brandyn': 1,
#  'feminists': 1,
#  'technological': 3,
#  'patriots-ponies': 1,
#  'preparations': 3,
#  'navigate': 7,
#  'bomber': 8,
#  'cornmeal': 1,
#  'unbeatable': 1,
#  'rounds': 5,
#  'tolkien': 3,
#  'piston': 2,
#  'hesterberg': 2,
#  'contentment': 1,
#  'blogs.tampabay.com/popmusic': 1,
#  'combustion': 3,
#  'poisons': 4,
#  'song-hee': 6,
#  'cndp': 2,
#  'harbingers': 1,
#  'sparingly': 2,
#  'suspension': 10,
#  'transform': 3,
#  'powerhouse': 3,
#  'mishandled': 2,
#  'werner': 1,
#  '38-3': 1,
#  'davie': 2,
#  'viewpoint': 2,
#  'artwork': 3,
#  'martinez': 20,
#  'arrived': 46,
#  'unborn': 2,
#  'approaching': 7,
#  'exciting': 12,
#  'castles': 1,
#  'chore': 1,
#  'rajon': 1,
#  'one-goal': 1,
#  'seekers': 5,
#  'devine': 5,
#  'gattis': 3,
#  '300,000': 7,
#  'dibs': 1,
#  'gailey': 2,
#  'concluding': 3,
#  'baffled': 2,
#  'shudder': 2,
#  'october': 75,
#  '952': 2,
#  '30,000': 4,
#  'diners': 2,
#  'adage': 4,
#  '3,500': 4,
#  'cluttered': 1,
#  'olive': 15,
#  '49-173-703-9485': 1,
#  'wholly': 5,
#  "francisco's": 4,
#  'fixing': 4,
#  'adm': 2,
#  'vaunted': 1,
#  'playoff': 18,
#  'anderson': 44,
#  'multiracial': 2,
#  'midswing': 1,
#  'jbenbow@globe.com': 1,
#  'madre': 1,
#  "dye's": 6,
#  'carried': 45,
#  'torque': 6,
#  'breathlessly': 2,
#  'payments': 34,
#  'mouths': 3,
#  'oncology': 2,
#  "archipelago's": 1,
#  'knock-off': 1,
#  'hung': 11,
#  'sense': 100,
#  'flagged': 3,
#  'teachers': 17,
#  'neighbors': 40,
#  'oram': 1,
#  'public': 256,
#  'maddon': 1,
#  "acquirer's": 1,
#  'wives': 5,
#  'navy': 14,
#  'velasquez': 2,
#  'square': 31,
#  'indian': 16,
#  '8:40': 2,
#  'melville': 4,
#  'pretended': 2,
#  'million--seeking': 1,
#  'blitzer': 4,
#  'abstinence-only': 1,
#  'moenjodaro': 1,
#  'hartley': 6,
#  'strait': 9,
#  'familiar': 39,
#  'young': 216,
#  'mowed': 3,
#  'rarely': 28,
#  'penn': 15,
#  'network-ratings': 1,
#  'paris': 22,
#  'superstitious': 4,
#  '884,000': 1,
#  'fax': 6,
#  'lowell': 14,
#  'rams': 15,
#  'dimmers': 1,
#  'walker': 5,
#  'stanton': 1,
#  'redistributionist': 2,
#  'utopia': 1,
#  'two-seat': 1,
#  'action': 57,
#  'barges': 6,
#  'assailed': 1,
#  'toys': 11,
#  'hannes': 1,
#  'nicknames': 1,
#  "reader's": 1,
#  'catch': 43,
#  'importantly': 1,
#  "israel's": 2,
#  'slung': 1,
#  'fs': 1,
#  'challenge': 59,
#  'midwest': 5,
#  'forever': 11,
#  'minh': 1,
#  'francois': 1,
#  'uninterested': 1,
#  'plots': 2,
#  'cubby': 4,
#  'eyebrow': 1,
#  'disarm': 1,
#  'insurers': 13,
#  "ledford's": 1,
#  'ill-fated': 1,
#  'fide': 2,
#  'authorities': 25,
#  '50-seat': 1,
#  'degganssptimes': 1,
#  'platoon': 1,
#  'prospect': 17,
#  'inept': 1,
#  'employees': 39,
#  'donner': 1,
#  'reid': 13,
#  'unflattering': 1,
#  'friend-friend': 1,
#  'kettles': 1,
#  'cartoons': 3,
#  'sluggish': 2,
#  'telegraph': 4,
#  'boulevards': 1,
#  'emirate': 3,
#  'stow': 2,
#  'squared': 2,
#  'lapels': 1,
#  'possessions': 8,
#  'meandering': 1,
#  'six-level': 1,
#  'pratt': 8,
#  'volunteer': 19,
#  'moan': 2,
#  'subtle': 7,
#  ...}

# %%
# b)
unique_words = len(text_set) #it's a set, so the elements are unique
print(unique_words)
# Out:
# 33155

# %%
# c)
vowel_groups = []
for word in text.lower().split():
    vow_group = ""
    for char in word:
        if char in "aeiou":
            vow_group+=char
            vowel_groups.append(vow_group)
        else:
            vow_group = ""

vowel_set = set(vowel_groups)
#vowel_freq = [vowel_groups.count(x) for x in vowel_set] # does not currently count overlapping groups, e.g. iia as 1, but aiia as 7
vowel_freq = [text.lower().count(x) for x in vowel_set]
vowel_freq_dict = {word:v_freq for word, v_freq in zip(vowel_set, vowel_freq)}
vowel_freq_dict = {k:v for k,v in sorted(vowel_freq_dict.items(), key=lambda x: x[1], reverse=True)}

# %%
vowel_freq_dict
# Out:
# {'e': 286904,
#  'a': 208486,
#  'o': 180005,
#  'i': 175776,
#  'u': 61342,
#  'ou': 17309,
#  'ea': 14435,
#  'io': 10975,
#  'ai': 10557,
#  'ee': 8054,
#  'ie': 6442,
#  'ia': 5351,
#  'oo': 4980,
#  'ei': 3364,
#  'au': 2470,
#  'ue': 2444,
#  'oi': 2026,
#  'ua': 1781,
#  'oa': 1651,
#  'eo': 1643,
#  'ui': 1635,
#  'oe': 750,
#  'iou': 506,
#  'eu': 471,
#  'ae': 244,
#  'iu': 218,
#  'eau': 131,
#  'uo': 103,
#  'ii': 101,
#  'aa': 81,
#  'ao': 75,
#  'oui': 63,
#  'eou': 61,
#  'eei': 60,
#  'uee': 56,
#  'uie': 44,
#  'aii': 30,
#  'aeu': 25,
#  'uou': 22,
#  'ieu': 19,
#  'uu': 10,
#  'iii': 10,
#  'oia': 9,
#  'iia': 8,
#  'oei': 7,
#  'aiia': 7,
#  'uea': 7,
#  'uai': 7,
#  'ooi': 6,
#  'ooe': 6,
#  'aou': 4,
#  'ioia': 4,
#  'ioi': 4,
#  'ueu': 3,
#  'eoi': 3,
#  'eie': 3,
#  'ooo': 3,
#  'iai': 2,
#  'oeu': 2,
#  'uoi': 2,
#  'eia': 2,
#  'oue': 2,
#  'eee': 2,
#  'ioe': 2,
#  'aee': 1,
#  'ueui': 1,
#  'ooie': 1,
#  'ioa': 1,
#  'eai': 1,
#  'eea': 1,
#  'aea': 1,
#  'ooooo': 1,
#  'oao': 1,
#  'oooo': 1,
#  'aoui': 1,
#  'eeee': 1,
#  'aeo': 1,
#  'oau': 1,
#  'oua': 1}

# %% [markdown]
# #### 2. Sorting and reversing lines of text
#
# a. Sort each line alphabetically (ignoring case).
# b. Sort in numeric ([ascii](https://python-reference.readthedocs.io/en/latest/docs/str/ASCII.html)) order.
# c. Alphabetically reverse sort (ignoring case).
# d. Sort in reverse numeric ([ascii](https://python-reference.readthedocs.io/en/latest/docs/str/ASCII.html)) order.

# %%
# a)
lines = text.lower().split("\n")

# %%
sorted_lines = lines.copy()
#sorted_lines = [l for l in sorted_lines if l!=""]
sorted_lines.sort()
print([l for l in sorted_lines if l!=""][0:100])
# Out:
# ['            the left      the middle      the right', '       11th district (parts of queens): james gennaro (d)', '       15th district (parts of queens): joseph addabbo (d)', '      "coach\'s decision," marbury said.', '      "coach\'s decision," marbury said.', '      "coach\'s decision," marbury said.', '      "we need to expect it," camarillo said. "we need to reach for', '      "we serve the saved and the unsaved."', '      &amp;lt;/td&gt;&amp;lt;/tr&gt;&amp;lt;tr&gt;&amp;lt;td&gt;senators', '      &amp;lt;/td&gt;&amp;lt;td&gt;0', '      &amp;lt;/td&gt;&amp;lt;td&gt;0', '      &amp;lt;/td&gt;&amp;lt;td&gt;0', '      &amp;lt;/td&gt;&amp;lt;td&gt;0', '      &amp;lt;/td&gt;&amp;lt;td&gt;1', '      &amp;lt;/td&gt;&amp;lt;td&gt;1', '      &amp;lt;/td&gt;&amp;lt;td&gt;2', '      &amp;lt;/td&gt;&amp;lt;td&gt;2', '      &amp;lt;/td&gt;&amp;lt;td&gt;3', "      '4:13 dream' (suretone/geffen)", "      'hemispheres' (artistshare)", "      'the renaissance' (motown)", "      'waking giant", "      'worst week'", '      (212) 556-4107, berrisnytimes.com', '      (212) 556-4107, berrisnytimes.com', '      (212) 556-4996, harrybnytimes.com', '      (212) 556-4996, harrybnytimes.com', '      (begin optional trim.)', '      (begin optional trim.)', '      (end optional trim.)', '      (number of daily flights)', '      (number of daily flights)', '      (will move in "a" news file.)', '      (will move in "f"\' news file.)', '      (will move in "f"\' news file.)', '      (will move in "i" news file.)', '      (will move in "s" news file.)', '      -- buy a modern television with a built-in digital tuner.', '      -- keep the old tv set and hook it to a converter box', '      -- peter baker', '      -- subscribe to cable, satellite or another pay service', '      -- the first black president', '      -- the first northern democrat elected president since kennedy', '      -- the first president born in hawaii', '      -- the first president from arizona', '      -- the first president who served in the vietnam war', '      -- the oldest person ever elected president for the first time', '      .      fast facts', '      .      fast facts', '      ..??overtime', '      1 1/2 teaspoons lea &amp;amp; perrins worcestershire sauce', '      1 1/2 teaspoons tomato paste', '      1 1/3 cups dry sherry', '      1 1/3 cups lamb stock', '      1 1/3 cups toasted almonds', '      1 1/4 pounds waxy potatoes, peeled and thinly sliced', '      1 14-ounce can chopped tomatoes', '      1 14-ounce can white beans, drained and rinsed', '      1 baguette, cubed and dried', '      1 bottle of fruity red wine, such as a garnacha', '      1 cinnamon stick', '      1 cup minced (about 1 medium) onion', '      1 large onion, cut into 1/2-inch dice', '      1 medium onion, thinly sliced', '      1 orange, peeled and sliced', '      1 p.m., bears by 12 1/2', '      1 p.m., browns by 1 1/2', '      1 p.m., buccaneers by 9', '      1 p.m., cardinals by 3', '      1 p.m., jaguars by 7 1/2', '      1 p.m., titans by 4 1/2', '      1 p.m., vikings by 4 1/2', '      1 pound boneless, skinless bonito or yellowfin tuna fillets', '      1 pound plum tomatoes (5 to 6, fresh or canned)', '      1 pound russet potatoes, boiled, peeled and chopped', '      1 splash of soda water', '      1 splash ruby port', '      1 strip of lemon zest', '      1 tablespoon finely chopped jam?n serrano (dry-cured spanish', '      1 tablespoon grand marnier or other orange liqueur (optional).', '      1 tablespoon ketchup', '      1 tablespoon lemon zest', '      1 teaspoon freshly ground black pepper', '      1. for how long will the titans remain undefeated?', '      1. lions 8 /6 /2 /1.000 / .750', '      1/2 cup dry white wine', '      1/2 cup flour', '      1/2 cup spanish extra-virgin olive oil, plus more for drizzling.', '      1/2 teaspoon dried oregano', '      1/2 teaspoon dried thyme', '      1/2 teaspoon unflavored gelatin', '      1/3 cup chopped fresh mint', '      1/3 cup dry sh ...

# %%
# b)
sort_ascii_forw = text.split("\n") # with caps, sort() sorts by ASCII
#sort_ascii_forw = sort_ascii_forw.sort(key = lambda x: sum(map(ord, x)))
sort_ascii_forw.sort()
print([l for l in sort_ascii_forw if l!=""][0:100])
# Out:
# ['            The left      The middle      The right', '       11th District (parts of Queens): James Gennaro (D)', '       15th District (parts of Queens): Joseph Addabbo (D)', '      "Coach\'s decision," Marbury said.', '      "Coach\'s decision," Marbury said.', '      "Coach\'s decision," Marbury said.', '      "We need to expect it," Camarillo said. "We need to reach for', '      "We serve the saved and the unsaved."', '      &amp;lt;/td&gt;&amp;lt;/tr&gt;&amp;lt;tr&gt;&amp;lt;td&gt;Senators', '      &amp;lt;/td&gt;&amp;lt;td&gt;0', '      &amp;lt;/td&gt;&amp;lt;td&gt;0', '      &amp;lt;/td&gt;&amp;lt;td&gt;0', '      &amp;lt;/td&gt;&amp;lt;td&gt;0', '      &amp;lt;/td&gt;&amp;lt;td&gt;1', '      &amp;lt;/td&gt;&amp;lt;td&gt;1', '      &amp;lt;/td&gt;&amp;lt;td&gt;2', '      &amp;lt;/td&gt;&amp;lt;td&gt;2', '      &amp;lt;/td&gt;&amp;lt;td&gt;3', "      '4:13 DREAM' (Suretone/Geffen)", "      'HEMISPHERES' (ArtistShare)", "      'THE RENAISSANCE' (Motown)", "      'WAKING GIANT", "      'Worst Week'", '      (212) 556-4107, berrisnytimes.com', '      (212) 556-4107, berrisnytimes.com', '      (212) 556-4996, harrybnytimes.com', '      (212) 556-4996, harrybnytimes.com', '      (BEGIN OPTIONAL TRIM.)', '      (BEGIN OPTIONAL TRIM.)', '      (END OPTIONAL TRIM.)', '      (Will move in "a" news file.)', '      (Will move in "f"\' news file.)', '      (Will move in "f"\' news file.)', '      (Will move in "i" news file.)', '      (Will move in "s" news file.)', '      (number of daily flights)', '      (number of daily flights)', '      -- Buy a modern television with a built-in digital tuner.', '      -- Keep the old TV set and hook it to a converter box', '      -- PETER BAKER', '      -- Subscribe to cable, satellite or another pay service', '      -- The first Northern Democrat elected president since Kennedy', '      -- The first black president', '      -- The first president born in Hawaii', '      -- The first president from Arizona', '      -- The first president who served in the Vietnam War', '      -- The oldest person ever elected president for the first time', '      .      fast facts', '      .      fast facts', '      ..??Overtime', '      1 1/2 teaspoons Lea &amp;amp; Perrins Worcestershire sauce', '      1 1/2 teaspoons tomato paste', '      1 1/3 cups dry sherry', '      1 1/3 cups lamb stock', '      1 1/3 cups toasted almonds', '      1 1/4 pounds waxy potatoes, peeled and thinly sliced', '      1 14-ounce can chopped tomatoes', '      1 14-ounce can white beans, drained and rinsed', '      1 baguette, cubed and dried', '      1 bottle of fruity red wine, such as a garnacha', '      1 cinnamon stick', '      1 cup minced (about 1 medium) onion', '      1 large onion, cut into 1/2-inch dice', '      1 medium onion, thinly sliced', '      1 orange, peeled and sliced', '      1 p.m., Bears by 12 1/2', '      1 p.m., Browns by 1 1/2', '      1 p.m., Buccaneers by 9', '      1 p.m., Cardinals by 3', '      1 p.m., Jaguars by 7 1/2', '      1 p.m., Titans by 4 1/2', '      1 p.m., Vikings by 4 1/2', '      1 pound boneless, skinless bonito or yellowfin tuna fillets', '      1 pound plum tomatoes (5 to 6, fresh or canned)', '      1 pound russet potatoes, boiled, peeled and chopped', '      1 splash of soda water', '      1 splash ruby port', '      1 strip of lemon zest', '      1 tablespoon Grand Marnier or other orange liqueur (optional).', '      1 tablespoon finely chopped jam?n Serrano (dry-cured Spanish', '      1 tablespoon ketchup', '      1 tablespoon lemon zest', '      1 teaspoon freshly ground black pepper', '      1. For how long will the Titans remain undefeated?', '      1. Lions 8 /6 /2 /1.000 / .750', '      1/2 cup Spanish extra-virgin olive oil, plus more for drizzling.', '      1/2 cup dry white wine', '      1/2 cup flour', '      1/2 teaspoon dried oregano', '      1/2 teaspoon dried thyme', '      1/2 teaspoon unflavored gelatin', '      1/3 cup chopped fresh mint', '      1/3 cup dry sh ...

# %%
# c)
sort_lines_rev = lines.copy()
sort_lines_rev.sort(reverse=True)

# %%
print(sort_lines_rev[:100])
# Out:
# ['zutell, of the office of insurance regulation, noted a problem', 'zurich.', 'zuma, speaking in soweto, seized on the notion of the dissidents', "zorn, buffalo's dick jauron, miami's tony sparano and, yes, even", "zone. coaches such as the late bill walsh and the seahawks' mike", 'zone, on first down. moreno was stuffed on an uninspired run on', "zone with the giants' fourth touchdown and a 28-7 lead. the rest of", 'zone for a 13-7 lead.', 'zogby concedes that "a letdown will come eventually.', 'zobel nolan, who has written more than 150 books, was a senior', 'zingers to warm things up between numbers. johnny, unhappy about', 'zingers and market-tested answers, prolonged exposure revealed', 'zimbabweans who are most in need of humanitarian response."', 'zimbabwe-aid (johannesburg, south africa) -- questions about the', "zimbabwe, due for consideration by the fund's board on friday,", "zimbabwe, due for consideration by the fund's board on friday,", "zimbabwe's information minister, sikhanyiso ndlovu, said sunday", "zimbabwe's capital, to donor nations and u.n. agencies, said in the", 'zigzagged', 'zhang was shoved to the ground by a local politician while visiting', 'zero." (the question was not predicated on whether obama would win', 'zero" chance of her becoming senate majority leader. several', 'zero', 'zeleny on the obama campaign, john m. broder on the biden campaign,', 'zealand. a victory or a draw against france in auckland on', 'zarei, a legislator close to ahmadinejad, slapped abbassi in the', 'zaragoza, which at peak capacity is capable of churning out more', "zaragoza's fate echoes the pattern now unfolding across spain", 'zaragoza was chosen to host the 2008 international exposition.', 'zaragoza kept booming even as the overbuilt mediterranean coast', 'zaragoza kept booming even as the overbuilt mediterranean coast', 'zaragoza kept booming even as the overbuilt mediterranean coast', 'zambian authorities do not want one that will hurt tourism.', 'zalis, as to pose "zero harm."', 'zalis dismissed the first concern; radiologists usually can', 'zaire, where ebola fever, which is not related, originated.', "zain haroon, general sales manager at hamer toyota, said he's", "zach cherny, 17, says it's important for teens to feel as though", 'zacarias moussaoui, as well as other foreign and domestic', 'yvonne abraham is globe columnist. her e-mail address is', 'yushchenko: "let\'s for once not get into these political dogfights', 'yushchenko, former political allies, are now locked in a power', 'yushchenko, former political allies, are now locked in a bitter', 'yushchenko, a former banker whose own popularity has plunged in', 'yushchenko has taken a combative approach toward russia, which', 'yushchenko has taken a combative approach toward russia, which', "yushchenko did not return the favor. he accused tymoshenko's", 'yunlin, the head of the association for relations across the taiwan', 'yulia mostova, editor in chief of dzerkalo tyzhnya, a weekly', "youtube's emergence as a vehicle for substantive discourse, not", 'youtube was just a fun way to burn off a few hours at work until', 'youth.', 'yourself," said levi forte, a bellman at the fontainebleau since', 'yourself by watching them back to back, you\'d see a through line,"', 'your tube', 'your team."', 'your team back down the stretch against a great team," harrell', 'your rival down.', 'your priorities, ask questions and get references and pictures,"', 'your portfolio into cash during such periods should produce', 'your portfolio in the safety of cash during times like these, when', 'your picture on it; a military id; a student id; a retirement', 'your pain.', 'your news.', 'your neighbors to the polls. i need your vote!"', 'your marital status does not matter here. if only one spouse is', 'your kids," he said.', 'your interest in reading the first page. his unique look and style', 'your favorite dried, small, hot chile pepper)', "your favorite chair no later than 7 p. ...

# %%
# d)
sort_ascii_rev = text.split("\n") # with caps, sort() sorts by ASCII
sort_ascii_rev.sort(reverse=True)
print(sort_ascii_rev[:100])
# Out:
# ["zone. Coaches such as the late Bill Walsh and the Seahawks' Mike", 'zone, on first down. Moreno was stuffed on an uninspired run on', "zone with the Giants' fourth touchdown and a 28-7 lead. The rest of", 'zone for a 13-7 lead.', 'zingers to warm things up between numbers. Johnny, unhappy about', 'zingers and market-tested answers, prolonged exposure revealed', 'zigzagged', 'zero." (The question was not predicated on whether Obama would win', 'zero" chance of her becoming Senate majority leader. Several', 'youth.', 'yourself," said Levi Forte, a bellman at the Fontainebleau since', 'yourself by watching them back to back, you\'d see a through line,"', 'your team."', 'your team back down the stretch against a great team," Harrell', 'your rival down.', 'your priorities, ask questions and get references and pictures,"', 'your portfolio into cash during such periods should produce', 'your portfolio in the safety of cash during times like these, when', 'your picture on it; a military ID; a student ID; a retirement', 'your pain.', 'your news.', 'your neighbors to the polls. I need your vote!"', 'your kids," he said.', 'your interest in reading the first page. His unique look and style', 'your favorite dried, small, hot chile pepper)', "your favorite chair no later than 7 p.m. Eastern time. (That's", 'your eyes', 'your doors," said Charles Tennant, hardware manager at Marine Home', 'your donkey." The Global Fund\'s management, known as the', 'your diet."', 'your chest.\' I knew what he meant: don\'t tell anybody."', 'your car right, in one space. You live right, you sleep in one bed.', 'your best', "your assistant coaches, you've really got to spend some additional", 'your (butt) kicked." K.C.\'s wild plays', 'your (butt) kicked."', 'your', 'youngest daughters run barefoot nearby. The girls stop to suck the', 'younger visitors.', 'younger players and the 10-year plan for the club, then he', 'younger man.', 'younger artists as Helen Frankenthaler, Jasper Johns, and Frank', 'young.)', 'young. I think I was maybe too young to have started straight', 'young-adult series such as Kimani TRU, Bluford, and Hotlanta for', 'young to be traveling."', 'young radical. "I was the quiet one who did all the work," he', "young players, those in the Knicks' future, those not named", 'young pitching (Jonathan Broxton seems to be a target). The Braves', 'young people voted compared with 1 in 14 for noncollege-going', 'young liberals meet a stone-cold scarcity that they do not seem to', 'young girl', 'young franchise star out of the loop, never mentioning it to', 'you: Good luck at the marathon, and I love you."', 'you.\' "', 'you."', 'you."', 'you. In this type of ballgame, it comes down to one possession, and', 'you," said', 'you," Obama said. "Two days."', 'you, which can take two weeks. Then comes certification class. Four', "you've-got-to-be-kidding-me grin while taking an unfamiliar place", "you've worn it one or two times, you don't feel as special in it.", 'you\'ve got to wait longer to see the results of the move."', 'you\'re under 21 and go to a party and there\'s alcohol," he says,', "you're passionate about winning. But scared?", "you're not so much worried about what's going to happen on the", 'you\'re labeled a terrorist, nobody does business with you."', 'you\'re labeled a terrorist, nobody does business with you."', "you're being yourself, because players, fans, and everyone else", 'you\'re beautiful."', "you're a tiny gal.", "you're 9, come back to them in about 10 years.", "you're", "you'll see Florida got a first-place vote. Despite losing to Ole", "you'd meet biologists over coffee, there'd be the same", "you'd lose your job - and that fear pushed you and made you the", 'you would not have been able to deliberate" and dismissed her.', 'you wish, but it was evident by their play against the Celtics in', 'you want, a self-guided tour.', "you want every day. It's about being smart and making the right", 'you vote for, I think every onc ...

# %% [markdown]
# #### 3. Computing basic statistics
#
# a. Find the 50 most common words
# b. Find the words in the NYT that end in "zz"
# c. Count the lines, the words, and the characters
# d. How many all uppercase words are there in this NYT file?
# e, How many 4-letter words?
# f. How many different words are there with no vowels?
# g. **tricky:** How many “1 syllable” words are there?

# %%
# a)
freq = {k: v for k, v in sorted(freq.items(), key = lambda item: item[1], reverse=True)}
freq
# Out:
# {'the': 29847,
#  'a': 13326,
#  'to': 12848,
#  'of': 12547,
#  'and': 12348,
#  'in': 11191,
#  'that': 5926,
#  'for': 5129,
#  'is': 4297,
#  'on': 4267,
#  'he': 3947,
#  'said': 3813,
#  'with': 3509,
#  'was': 3467,
#  'it': 3303,
#  'at': 3076,
#  'as': 3007,
#  'his': 2787,
#  'but': 2562,
#  'be': 2449,
#  'have': 2441,
#  'by': 2345,
#  'are': 2205,
#  'has': 2185,
#  'not': 2093,
#  'from': 2086,
#  'i': 2059,
#  'an': 2044,
#  'this': 1838,
#  'they': 1836,
#  'who': 1833,
#  'had': 1583,
#  'we': 1523,
#  'their': 1494,
#  'about': 1430,
#  'will': 1382,
#  'or': 1371,
#  'more': 1351,
#  'one': 1311,
#  'were': 1287,
#  'you': 1221,
#  'when': 1190,
#  'new': 1189,
#  'would': 1181,
#  'she': 1162,
#  'been': 1142,
#  'if': 1104,
#  'her': 1040,
#  'up': 1032,
#  'obama': 1007,
#  'all': 984,
#  'which': 978,
#  'out': 976,
#  'than': 951,
#  'there': 949,
#  'like': 941,
#  'so': 892,
#  'what': 889,
#  'its': 889,
#  'after': 867,
#  'last': 834,
#  'can': 830,
#  'people': 822,
#  'no': 820,
#  'just': 803,
#  'time': 798,
#  'could': 792,
#  'two': 790,
#  'some': 789,
#  'first': 779,
#  'other': 777,
#  "it's": 775,
#  'into': 753,
#  'mccain': 729,
#  'years': 725,
#  'him': 720,
#  'now': 703,
#  'over': 691,
#  'also': 688,
#  'them': 678,
#  'year': 659,
#  'do': 649,
#  'many': 649,
#  'most': 643,
#  'because': 630,
#  'only': 603,
#  'even': 578,
#  'state': 574,
#  'percent': 569,
#  'campaign': 566,
#  'president': 554,
#  'how': 539,
#  'get': 532,
#  'my': 530,
#  'election': 518,
#  'where': 518,
#  'did': 503,
#  'back': 486,
#  'going': 481,
#  'three': 475,
#  'those': 471,
#  'day': 468,
#  'our': 455,
#  'still': 455,
#  'before': 443,
#  'states': 435,
#  'game': 434,
#  'made': 434,
#  'while': 429,
#  'down': 429,
#  'then': 425,
#  'much': 424,
#  'say': 424,
#  'million': 418,
#  'since': 413,
#  'way': 413,
#  'against': 413,
#  'news': 413,
#  'here': 406,
#  'government': 403,
#  'think': 395,
#  'make': 391,
#  'through': 388,
#  'off': 387,
#  "don't": 385,
#  'week': 384,
#  'says': 380,
#  'times': 373,
#  'home': 373,
#  'go': 372,
#  'may': 370,
#  'voters': 368,
#  'john': 368,
#  'me': 363,
#  'american': 359,
#  'both': 358,
#  'team': 352,
#  'any': 350,
#  'good': 342,
#  'political': 340,
#  'florida': 339,
#  'season': 336,
#  'world': 330,
#  'these': 329,
#  'york': 327,
#  'next': 327,
#  'big': 326,
#  'long': 325,
#  'around': 325,
#  'right': 324,
#  'work': 322,
#  'republican': 321,
#  'during': 320,
#  'presidential': 318,
#  'too': 317,
#  'well': 315,
#  'see': 314,
#  'being': 314,
#  'money': 311,
#  'days': 309,
#  'take': 308,
#  'such': 307,
#  'city': 302,
#  'us': 302,
#  'know': 301,
#  'want': 297,
#  'another': 294,
#  "i'm": 293,
#  "that's": 292,
#  'never': 292,
#  'four': 288,
#  'very': 287,
#  'end': 287,
#  'lot': 287,
#  'house': 286,
#  'between': 285,
#  'might': 284,
#  'monday': 282,
#  'part': 282,
#  'best': 276,
#  'night': 275,
#  'officials': 275,
#  'play': 275,
#  'own': 271,
#  'vote': 270,
#  'come': 270,
#  'school': 270,
#  'democratic': 268,
#  'win': 268,
#  'your': 267,
#  'won': 267,
#  'early': 266,
#  'got': 265,
#  'including': 264,
#  'national': 262,
#  'help': 261,
#  'university': 260,
#  'should': 259,
#  'sen': 259,
#  'public': 256,
#  'every': 256,
#  'left': 254,
#  'really': 254,
#  'little': 254,
#  'ago': 253,
#  'life': 253,
#  'according': 253,
#  'country': 253,
#  'sunday': 250,
#  'former': 249,
#  'need': 249,
#  'called': 248,
#  'same': 248,
#  'polls': 245,
#  'few': 244,
#  "he's": 243,
#  'until': 240,
#  'among': 239,
#  'financial': 238,
#  'company': 236,
#  "didn't": 232,
#  'party': 232,
#  'second': 230,
#  'use': 229,
#  'each': 228,
#  'came': 228,
#  'recent': 228,
#  'business': 226,
#  '1': 226,
#  'great': 225,
#  'games': 223,
#  'tuesday': 222,
#  'running': 222,
#  'found': 219,
#  'yards': 219,
#  'put': 218,
#  'war': 217,
#  'under': 217,
#  'bush': 217,
#  'united': 217,
#  'young': 216,
#  'race': 215,
#  'barack': 214,
#  'things': 214,
#  "we're": 212,
#  'market': 212,
#  'told': 212,
#  'look': 212,
#  'place': 211,
#  'white': 211,
#  'used': 211,
#  'billion': 210,
#  'high': 210,
#  'bank': 210,
#  'took': 210,
#  'office': 210,
#  'past': 207,
#  'south': 206,
#  'why': 206,
#  'five': 205,
#  'run': 205,
#  'better': 204,
#  'least': 203,
#  'set': 201,
#  'black': 200,
#  'month': 199,
#  'become': 196,
#  'once': 196,
#  'history': 196,
#  'less': 195,
#  'line': 194,
#  'military': 194,
#  'something': 194,
#  'without': 194,
#  'later': 193,
#  "there's": 192,
#  'economic': 191,
#  'away': 190,
#  'economy': 190,
#  'making': 190,
#  'several': 189,
#  'palin': 188,
#  'point': 188,
#  'local': 188,
#  'show': 187,
#  'case': 187,
#  'close': 186,
#  'democrats': 186,
#  'lead': 186,
#  '10': 185,
#  'enough': 185,
#  'group': 184,
#  'hard': 184,
#  'voting': 184,
#  'does': 182,
#  'again': 179,
#  'keep': 178,
#  'went': 178,
#  'small': 177,
#  'often': 177,
#  'though': 176,
#  'coach': 176,
#  'man': 176,
#  'u.s': 175,
#  'children': 175,
#  'far': 175,
#  'health': 174,
#  'washington': 173,
#  '2004': 173,
#  'family': 172,
#  'third': 172,
#  'find': 171,
#  'republicans': 171,
#  'center': 171,
#  'whether': 171,
#  'others': 171,
#  'players': 170,
#  'old': 170,
#  'companies': 169,
#  'top': 169,
#  'half': 169,
#  'lost': 168,
#  'weeks': 168,
#  'late': 167,
#  "obama's": 167,
#  'thought': 167,
#  '20': 167,
#  'college': 167,
#  'nearly': 166,
#  'final': 166,
#  'victory': 165,
#  '2': 161,
#  'months': 160,
#  'likely': 160,
#  'deal': 159,
#  'banks': 159,
#  'change': 159,
#  'series': 159,
#  'sales': 158,
#  'police': 158,
#  'north': 157,
#  'report': 157,
#  'job': 157,
#  'bill': 157,
#  'played': 156,
#  'feel': 156,
#  'already': 156,
#  'service': 156,
#  'general': 156,
#  'p.m': 156,
#  'call': 155,
#  'began': 155,
#  'field': 154,
#  'getting': 154,
#  'yet': 154,
#  'almost': 153,
#  'always': 153,
#  'side': 153,
#  'program': 152,
#  'director': 152,
#  'trying': 152,
#  'whose': 151,
#  'students': 151,
#  'chief': 150,
#  'system': 150,
#  'given': 150,
#  'food': 149,
#  'different': 148,
#  'give': 148,
#  'asked': 147,
#  'private': 147,
#  'number': 147,
#  'important': 146,
#  'expected': 146,
#  'points': 146,
#  'thing': 146,
#  "they're": 145,
#  'real': 144,
#  'bad': 144,
#  'senate': 144,
#  'saturday': 144,
#  'major': 144,
#  'ever': 144,
#  'court': 142,
#  "can't": 142,
#  'chance': 142,
#  'america': 142,
#  'seen': 142,
#  'minutes': 142,
#  'crisis': 141,
#  'federal': 140,
#  'television': 140,
#  'pay': 140,
#  'texas': 140,
#  'friday': 139,
#  'defense': 139,
#  'street': 139,
#  '8': 138,
#  'hours': 138,
#  'looking': 137,
#  'clinton': 137,
#  'media': 137,
#  'large': 136,
#  'along': 136,
#  '4': 136,
#  'pass': 135,
#  'candidates': 135,
#  'reached': 135,
#  'red': 134,
#  'kind': 134,
#  'law': 133,
#  'probably': 132,
#  'tampa': 132,
#  'start': 132,
#  '30': 131,
#  'smith': 131,
#  'open': 131,
#  'across': 131,
#  '3': 131,
#  'himself': 131,
#  'support': 131,
#  'done': 130,
#  'free': 130,
#  'power': 130,
#  '15': 130,
#  'today': 130,
#  'working': 129,
#  'added': 129,
#  'behind': 129,
#  'denver': 128,
#  'county': 127,
#  'coming': 127,
#  'site': 125,
#  'six': 125,
#  'started': 125,
#  'industry': 125,
#  'question': 124,
#  'recently': 123,
#  'politics': 123,
#  'known': 123,
#  'seems': 123,
#  'women': 123,
#  'turn': 122,
#  'spent': 122,
#  'virginia': 122,
#  'guys': 122,
#  "you're": 121,
#  'having': 121,
#  '5': 121,
#  'west': 121,
#  'cut': 120,
#  'votes': 120,
#  'problem': 120,
#  'rally': 119,
#  'security': 119,
#  'try': 119,
#  'held': 118,
#  'turned': 118,
#  'room': 118,
#  'colorado': 118,
#  'able': 118,
#  'issue': 118,
#  'live': 117,
#  "i've": 117,
#  'wrote': 117,
#  'face': 117,
#  'ohio': 117,
#  'teams': 117,
#  'americans': 116,
#  'brown': 116,
#  'david': 116,
#  'air': 116,
#  'candidate': 116,
#  'men': 116,
#  'football': 115,
#  "doesn't": 115,
#  "we've": 115,
#  'department': 115,
#  'especially': 115,
#  'believe': 115,
#  'george': 114,
#  'quarterback': 114,
#  'book': 114,
#  'biggest': 114,
#  'taken': 114,
#  'instead': 114,
#  'playing': 114,
#  'congress': 113,
#  'quarter': 113,
#  'spending': 113,
#  'members': 112,
#  'goal': 112,
#  'together': 112,
#  'sure': 112,
#  'research': 112,
#  'move': 112,
#  'matter': 111,
#  'touchdown': 111,
#  'doing': 111,
#  'iraq': 111,
#  'name': 111,
#  'problems': 110,
#  'league': 110,
#  "mccain's": 110,
#  'talk': 109,
#  'district': 109,
#  'age': 109,
#  'eight': 109,
#  'based': 108,
#  'web': 108,
#  'georgia': 108,
#  '2008': 108,
#  "wasn't": 108,
#  'let': 108,
#  'executive': 107,
#  'calls': 107,
#  'mark': 107,
#  'elections': 107,
#  'head': 106,
#  'interest': 106,
#  'global': 106,
#  'care': 106,
#  'california': 106,
#  'loss': 105,
#  'september': 105,
#  'anything': 105,
#  'helped': 105,
#  'despite': 104,
#  'decision': 104,
#  'credit': 104,
#  'taking': 104,
#  '11': 104,
#  'interview': 104,
#  'hope': 104,
#  'outside': 104,
#  'morning': 104,
#  'hit': 104,
#  'wanted': 104,
#  'story': 103,
#  'tv': 103,
#  'moved': 103,
#  'future': 103,
#  '2007': 103,
#  'record': 103,
#  'must': 102,
#  'became': 102,
#  'patriots': 102,
#  'either': 102,
#  'wife': 102,
#  'brought': 102,
#  'love': 101,
#  'return': 101,
#  'although': 101,
#  'comes': 101,
#  'community': 101,
#  'sense': 100,
#  'capital': 100,
#  'near': 100,
#  'reported': 100,
#  'force': 100,
#  'plan': 100,
#  'example': 99,
#  'san': 99,
#  'led': 99,
#  'bucs': 99,
#  'policy': 99,
#  'title': 99,
#  'oil': 98,
#  'ballots': 98,
#  'mother': 98,
#  'current': 98,
#  'middle': 98,
#  'stop': 98,
#  'someone': 98,
#  'veterans': 98,
#  'attack': 97,
#  'person': 97,
#  'gone': 97,
#  'ball': 97,
#  'park': 97,
#  'seven': 97,
#  'st': 97,
#  'supporters': 97,
#  '2006': 97,
#  'gave': 97,
#  'front': 97,
#  'clear': 96,
#  'staff': 96,
#  '6': 96,
#  'works': 96,
#  'information': 96,
#  'perhaps': 96,
#  'saw': 96,
#  'issues': 96,
#  'sent': 96,
#  'full': 96,
#  'sometimes': 95,
#  'nothing': 95,
#  'everything': 95,
#  'makes': 95,
#  'administration': 95,
#  'buy': 95,
#  'building': 94,
#  'bay': 94,
#  'services': 94,
#  'saying': 94,
#  'difficult': 94,
#  'father': 94,
#  'army': 94,
#  'list': 93,
#  '12': 93,
#  'hotel': 93,
#  'bring': 93,
#  'career': 93,
#  'boston': 93,
#  'however': 93,
#  'official': 92,
#  'safety': 92,
#  'worked': 92,
#  'tech': 92,
#  'democrat': 92,
#  'tried': 92,
#  'role': 92,
#  '18': 92,
#  'foreign': 92,
#  'vice': 91,
#  'earlier': 91,
#  'include': 91,
#  'lives': 91,
#  'road': 91,
#  'effort': 91,
#  'player': 91,
#  'markets': 91,
#  'price': 90,
#  'knew': 90,
#  'possible': 90,
#  'ground': 90,
#  'board': 89,
#  'town': 89,
#  'leaders': 89,
#  'michael': 89,
#  '7': 89,
#  'course': 89,
#  'manager': 89,
#  'miami': 89,
#  'seemed': 89,
#  'plays': 88,
#  'toward': 88,
#  'couple': 88,
#  'guy': 88,
#  'cast': 88,
#  'poll': 88,
#  'winning': 88,
#  'area': 87,
#  'means': 87,
#  'senior': 87,
#  'experience': 87,
#  'drug': 87,
#  'car': 87,
#  'bit': 87,
#  'needed': 87,
#  'thousands': 86,
#  'williams': 86,
#  'jobs': 86,
#  'oct': 86,
#  'rather': 86,
#  'shows': 86,
#  'tax': 86,
#  'fall': 86,
#  'total': 85,
#  'anyone': 85,
#  'friends': 85,
#  'books': 85,
#  '25': 85,
#  'international': 85,
#  'water': 85,
#  'seem': 85,
#  'voted': 85,
#  'hold': 85,
#  'workers': 85,
#  'strong': 85,
#  'network': 84,
#  'soon': 84,
#  'woman': 84,
#  'idea': 84,
#  'weekend': 84,
#  "isn't": 84,
#  'stock': 84,
#  'starting': 83,
#  'special': 83,
#  'a.m': 83,
#  'died': 83,
#  'fact': 83,
#  'prices': 83,
#  '100': 83,
#  'questions': 83,
#  'conference': 82,
#  'energy': 82,
#  'fourth': 82,
#  'primary': 82,
#  'tough': 82,
#  'colts': 82,
#  'themselves': 82,
#  'period': 82,
#  'needs': 82,
#  'evidence': 82,
#  'fans': 81,
#  'process': 81,
#  'showed': 81,
#  'rate': 81,
#  'test': 81,
#  'mike': 81,
#  'leading': 81,
#  'professor': 81,
#  'conservative': 80,
#  'read': 80,
#  'leader': 80,
#  'fund': 80,
#  'wall': 80,
#  'actually': 80,
#  'e-mail': 80,
#  "won't": 80,
#  'huge': 80,
#  'joe': 80,
#  'los': 80,
#  'short': 80,
#  '40': 79,
#  'giving': 79,
#  'british': 79,
#  'cash': 79,
#  'results': 79,
#  'social': 79,
#  'yes': 79,
#  'carolina': 79,
#  'division': 79,
#  'johnson': 79,
#  'central': 79,
#  'voter': 78,
#  'using': 78,
#  'attention': 78,
#  'within': 78,
#  'bowl': 78,
#  'crowd': 78,
#  'broncos': 78,
#  'itself': 78,
#  'sarah': 78,
#  'battle': 78,
#  'fight': 78,
#  'meeting': 78,
#  'maybe': 78,
#  'reason': 78,
#  'miles': 78,
#  'pennsylvania': 78,
#  'coverage': 77,
#  'plans': 77,
#  'movie': 77,
#  'nov': 77,
#  'minister': 77,
#  'potential': 77,
#  'decades': 77,
#  'angeles': 77,
#  'rights': 77,
#  'tell': 77,
#  'governor': 77,
#  'whom': 77,
#  'loans': 76,
#  'paid': 76,
#  'insurance': 76,
#  'killed': 76,
#  'received': 76,
#  'wrong': 76,
#  'level': 76,
#  'marriage': 76,
#  'felt': 76,
#  'worst': 76,
#  'risk': 76,
#  'october': 75,
#  'happen': 75,
#  'son': 75,
#  'stay': 75,
#  'rest': 75,
#  'hour': 75,
#  'sign': 75,
#  'chicago': 75,
#  'words': 75,
#  'looked': 75,
#  'summer': 75,
#  'campaigns': 75,
#  'chairman': 75,
#  'east': 75,
#  'art': 74,
#  'remaining': 74,
#  'super': 74,
#  '13': 74,
#  'marathon': 74,
#  'cannot': 74,
#  'ways': 74,
#  'talking': 74,
#  'french': 74,
#  'online': 74,
#  'internet': 74,
#  'certain': 74,
#  'turnout': 74,
#  'thursday': 74,
#  'ballot': 74,
#  'largest': 73,
#  'offered': 73,
#  'forces': 73,
#  'whole': 73,
#  'friend': 73,
#  'bills': 73,
#  'everyone': 73,
#  'families': 73,
#  'phone': 73,
#  'heard': 73,
#  'nfl': 73,
#  'citizens': 73,
#  'husband': 73,
#  'gov': 73,
#  'presidency': 73,
#  'death': 72,
#  'leave': 72,
#  'single': 72,
#  'film': 72,
#  'student': 72,
#  'provide': 72,
#  'ahead': 72,
#  'groups': 72,
#  'museum': 72,
#  'class': 72,
#  'robert': 72,
#  'island': 72,
#  'available': 72,
#  'wants': 72,
#  'pretty': 71,
#  '9': 71,
#  'lines': 71,
#  '2000': 71,
#  'massachusetts': 71,
#  'control': 71,
#  'announced': 71,
#  'nominee': 71,
#  'moment': 71,
#  'result': 71,
#  'investment': 70,
#  'reach': 70,
#  'stories': 70,
#  'released': 70,
#  'step': 70,
#  'agent': 70,
#  'sports': 70,
#  'cost': 70,
#  'fell': 70,
#  'wednesday': 70,
#  'post': 69,
#  'body': 69,
#  'church': 69,
#  'wins': 69,
#  'nation': 69,
#  'amp;amp': 69,
#  'terms': 69,
#  'particularly': 69,
#  'stadium': 69,
#  "country's": 69,
#  'marbury': 69,
#  'share': 69,
#  'declined': 69,
#  'equity': 69,
#  'james': 69,
#  'average': 69,
#  'philadelphia': 69,
#  'floor': 68,
#  'continue': 68,
#  'detroit': 68,
#  'beyond': 68,
#  'countries': 68,
#  'parents': 68,
#  'word': 68,
#  'video': 68,
#  'offense': 68,
#  'drive': 68,
#  'key': 68,
#  'living': 68,
#  '17': 68,
#  'meet': 68,
#  'serious': 68,
#  "couldn't": 68,
#  "what's": 67,
#  'legal': 67,
#  'sept': 67,
#  'areas': 67,
#  'contract': 67,
#  'committee': 67,
#  'thomas': 67,
#  'dollars': 67,
#  'longer': 67,
#  'shot': 67,
#  'decided': 67,
#  'm': 67,
#  'position': 67,
#  'electoral': 67,
#  'base': 67,
#  'daughter': 67,
#  'nine': 67,
#  'takes': 66,
#  'offer': 66,
#  'firm': 66,
#  'higher': 66,
#  'giants': 66,
#  'data': 66,
#  'changed': 66,
#  'schools': 66,
#  'investors': 66,
#  'spokesman': 66,
#  "nation's": 66,
#  'production': 66,
#  'green': 66,
#  'hand': 66,
#  'budget': 65,
#  'am': 65,
#  'raised': 65,
#  '50': 65,
#  'debt': 65,
#  'reporters': 65,
#  'happened': 65,
#  'impact': 65,
#  'radio': 65,
#  'loan': 64,
#  'situation': 64,
#  'rock': 64,
#  'sold': 64,
#  'lose': 64,
#  'housing': 64,
#  'cbs': 64,
#  'ran': 64,
#  'quickly': 64,
#  'goes': 64,
#  'visit': 64,
#  'speech': 64,
#  'education': 64,
#  'remains': 64,
#  'alaska': 64,
#  'form': 64,
#  'trade': 64,
#  'numbers': 64,
#  'technology': 64,
#  'begin': 63,
#  'appeared': 63,
#  'allowed': 63,
#  'aid': 63,
#  'dropped': 63,
#  'project': 63,
#  'measure': 63,
#  'built': 63,
#  'similar': 63,
#  'consumers': 63,
#  'twice': 63,
#  '21': 63,
#  'reports': 63,
#  'inside': 63,
#  'met': 63,
#  'failed': 63,
#  'sites': 63,
#  'fox': 63,
#  'efforts': 63,
#  'soldiers': 63,
#  'd': 63,
#  'jets': 63,
#  'personal': 63,
#  'q': 62,
#  'traditional': 62,
#  'low': 62,
#  'break': 62,
#  'passed': 62,
#  'japanese': 62,
#  'zone': 62,
#  'hundreds': 62,
#  'jr': 62,
#  'event': 62,
#  'organization': 62,
#  'hands': 62,
#  'study': 62,
#  'financing': 61,
#  'quite': 61,
#  '2005': 61,
#  'championship': 61,
#  'per': 61,
#  'member': 61,
#  'remain': 61,
#  'martin': 61,
#  'allow': 61,
#  '16': 61,
#  'analysts': 61,
#  'nba': 61,
#  'cases': 61,
#  'parts': 61,
#  'practice': 61,
#  'mind': 61,
#  'advertising': 61,
#  'afternoon': 61,
#  ...}

# %%
# b)
text_set = set(text_list)
[zz for zz in text_set if zz[-2:]=="zz"]
# Out:
# ['pizazz', 'jazz', 'buzz']

# %%
# c)
lines_len = len(text_lower.split("\n"))

# %%
words_len = len(text_set)

# %%
char_len = len(text_lower)

# %%
print("Lines:{0}\nWords:{1}\nChars:{2}".format(lines_len, words_len, char_len))
# Out:
# Lines:70335
# Words:33156
# Chars:3052299

# %%
# d)
len([big for big in text.split(" ") if big.isupper()])
# Out:
# 4955

# %%
# e)
four_list = [four for four in text_list if len(four)==4]
four_list = [four for four in four_list if four.isalpha()]
len(four_list)
# Out:
# 82363

# %%
# f)
only_consonant = []
words_list = [w for w in text_list if w.isalpha()]
word_set = set(words_list) # assure unique words
for word in word_set:
    consonant_word = True
    for char in word:
        if char in "aeiou":
            consonant_word = False
            break
    only_consonant.append(word) if consonant_word else None

print(len(only_consonant)) # "words" 
only_consonant
# Out:
# 225
# ['vq',
#  'mst',
#  'wms',
#  'pc',
#  'gmc',
#  'cndp',
#  'fs',
#  'l',
#  'tr',
#  'pp',
#  'dc',
#  'sgt',
#  'dt',
#  'q',
#  'b',
#  'lg',
#  'myth',
#  'jbs',
#  'ty',
#  'rhs',
#  'lynd',
#  'tjx',
#  'pg',
#  'bcs',
#  'pm',
#  'hd',
#  'vp',
#  'wsjt',
#  'kcnc',
#  'bbc',
#  'nytns',
#  'pnc',
#  'z',
#  'bc',
#  'lx',
#  'y',
#  'fb',
#  'ky',
#  'rb',
#  'tv',
#  'tlc',
#  'qb',
#  'psych',
#  'xm',
#  'cnbc',
#  'gps',
#  'phd',
#  'tk',
#  'rw',
#  'mpc',
#  'ny',
#  'mdc',
#  'syd',
#  'kpmg',
#  'fcc',
#  'rhythm',
#  'dpp',
#  'ws',
#  'cd',
#  'lt',
#  'cbs',
#  'rhythms',
#  'bmw',
#  'rv',
#  'fdr',
#  'hmc',
#  'wryly',
#  'lynch',
#  'sly',
#  'crp',
#  'sls',
#  'dnc',
#  'ldl',
#  'c',
#  'ch',
#  'mls',
#  'qbs',
#  'blyth',
#  'f',
#  'dhl',
#  'mrs',
#  'by',
#  'shy',
#  'xp',
#  'nhl',
#  'll',
#  'ypm',
#  'pct',
#  'hsbc',
#  'cyr',
#  'msg',
#  'nypd',
#  'dtv',
#  'mj',
#  'g',
#  'gms',
#  'flynn',
#  'ct',
#  'vs',
#  'fgs',
#  'st',
#  'pbs',
#  'lb',
#  'html',
#  'cb',
#  'rbc',
#  'sccc',
#  'dvds',
#  'sxt',
#  'j',
#  'dr',
#  'csm',
#  'nfc',
#  'tnt',
#  'my',
#  'ds',
#  'mf',
#  'fry',
#  'ddt',
#  'cmdr',
#  'k',
#  'why',
#  'gdp',
#  'w',
#  'kc',
#  'cds',
#  'trysts',
#  'myths',
#  'ng',
#  'cy',
#  'pry',
#  'm',
#  'htm',
#  'tsb',
#  'wry',
#  'mvp',
#  'td',
#  'wmm',
#  'mtv',
#  'md',
#  'plc',
#  'tpg',
#  'kbr',
#  'msnbc',
#  'dj',
#  'kmt',
#  'tyc',
#  'dry',
#  'tvs',
#  'ltd',
#  'km',
#  'fl',
#  'nfl',
#  'rs',
#  'dvr',
#  'sky',
#  'gq',
#  'tb',
#  'ls',
#  'dvd',
#  'fly',
#  'hdtv',
#  'cc',
#  'skynyrd',
#  'try',
#  'n',
#  'jfk',
#  'thq',
#  't',
#  'strs',
#  'cry',
#  'kkr',
#  'lynn',
#  'djs',
#  'nyt',
#  'jr',
#  'dmk',
#  'blvd',
#  'thy',
#  'wr',
#  'ps',
#  'gm',
#  'bff',
#  'cpl',
#  'nl',
#  'mpg',
#  'x',
#  'cnn',
#  'spy',
#  'r',
#  'sr',
#  'hvs',
#  'cyst',
#  'h',
#  'hymns',
#  'npd',
#  'llc',
#  'nbc',
#  'ss',
#  'rjc',
#  'p',
#  's',
#  'mr',
#  'hdl',
#  'snl',
#  'wsm',
#  'fbs',
#  'sb',
#  'ms',
#  'd',
#  'mph',
#  'bnp',
#  'mgm',
#  'bryn',
#  'cw',
#  'qvc',
#  'mt',
#  'rt',
#  'gym',
#  'npr',
#  'wynn',
#  'tds',
#  'lcd',
#  'v',
#  'str']

# %%
len(only_consonant)
# Out:
# 225

# %%
# g)
s_vowels = "aeiouy"
# onset {consonant cluster} + nucleus {aeiouy or as one unit, like ee in week or oi in coin} or  + coda {consonant cluster}

monosyllabic = [word for word in word_set if sum([1 for char in word if char in s_vowels])<=2] # potential monosyllabic words
two_vowel = set(vg for vg in vowel_set if len(vg)==2) # potential vowel groups

# %%
# I give up
"""for word in monosyllabic:
    # if Cons + two Vowel Group  + Cons -> 1 syllable
    if sum([1 for char in word if char in s_vowels])>1:
        for i in range(len(word)-2):
            if len(word)>=4:
                if word[i] not in s_vowels and word[i+1:i+3] in two_vowel and word[i+3] not in s_vowels:
                    continue
                elif #:
                    
                else:
                    monosyllabic.remove(word)
                    break"""

# %%
monosyllabic = [word for word in word_set if sum([1 for char in word if char in s_vowels])<=1]

# %%
monosyllabic
# Out:
# ['mem',
#  'arzt',
#  'spots',
#  'buts',
#  'scrap',
#  'di',
#  'ba',
#  'mug',
#  'amc',
#  'vq',
#  'kirk',
#  'sad',
#  'chaz',
#  'grills',
#  'ac',
#  'mst',
#  'tag',
#  'mel',
#  'chris',
#  'clam',
#  'ron',
#  'wms',
#  'hal',
#  'chip',
#  'na',
#  'lom',
#  'prompt',
#  'herd',
#  'plugs',
#  'paths',
#  'sips',
#  'night',
#  'didnt',
#  'starts',
#  'shag',
#  'pc',
#  'scar',
#  'did',
#  'gmc',
#  'dim',
#  'sins',
#  'tug',
#  'ills',
#  'bled',
#  'mum',
#  'vip',
#  'lap',
#  'par',
#  'flat',
#  'kang',
#  'rack',
#  'eds',
#  'um',
#  'lets',
#  'irv',
#  'rocks',
#  'flinch',
#  'cndp',
#  'dibs',
#  'adm',
#  'hung',
#  'penn',
#  'fax',
#  'rams',
#  'catch',
#  'slung',
#  'fs',
#  'minh',
#  'plots',
#  'stow',
#  'pratt',
#  'richt',
#  'swamps',
#  'pal',
#  'split',
#  'flown',
#  'bold',
#  'glib',
#  'stats',
#  'frowns',
#  'chi',
#  'loss',
#  'l',
#  'ton',
#  'tr',
#  'zorn',
#  'month',
#  'stiff',
#  'crumbs',
#  'uf',
#  'fights',
#  'pp',
#  'stars',
#  'jack',
#  'beds',
#  'rust',
#  'and',
#  'gogh',
#  'turns',
#  'e',
#  'small',
#  'crops',
#  'grab',
#  'flats',
#  'sin',
#  'set',
#  'dc',
#  'winds',
#  'shown',
#  'slug',
#  'flow',
#  'scan',
#  'theft',
#  'er',
#  'ports',
#  'bug',
#  'bu',
#  'brann',
#  'pep',
#  'clapp',
#  'garb',
#  'kim',
#  'ad',
#  'dish',
#  'ur',
#  'tenth',
#  'lob',
#  'shah',
#  'tpi',
#  'sketch',
#  'scoff',
#  'shirt',
#  'dang',
#  'vin',
#  'czar',
#  'ahh',
#  'zip',
#  'gop',
#  'flows',
#  'lug',
#  'grass',
#  'platt',
#  'sgt',
#  'length',
#  'know',
#  'dt',
#  'firm',
#  'frog',
#  'glass',
#  'long',
#  'clubs',
#  'q',
#  'daft',
#  'b',
#  'flew',
#  'ranks',
#  'horns',
#  'pumps',
#  'sic',
#  'pork',
#  'slip',
#  'trap',
#  'storms',
#  'jocks',
#  'claw',
#  'scarf',
#  'shawn',
#  'swirl',
#  'mint',
#  'pin',
#  'prints',
#  'strung',
#  'kemp',
#  'bronx',
#  'sick',
#  'ross',
#  'brush',
#  'chill',
#  'debts',
#  'scents',
#  'bust',
#  'mud',
#  'bland',
#  'crowds',
#  'lush',
#  'csob',
#  'lg',
#  'vast',
#  'i',
#  'gulf',
#  'myth',
#  'sod',
#  'mac',
#  'schwartz',
#  'warmth',
#  'legs',
#  'was',
#  'wilt',
#  'usfl',
#  'feld',
#  'lifts',
#  'logs',
#  'skip',
#  'shock',
#  'cal',
#  'ill',
#  'calf',
#  'bless',
#  'damp',
#  'smirk',
#  'jobs',
#  'held',
#  'walsh',
#  'surf',
#  'brett',
#  'gun',
#  'jeff',
#  'drink',
#  'la',
#  'swills',
#  'whips',
#  'fans',
#  'rich',
#  'switch',
#  'clint',
#  'back',
#  'sell',
#  'ghent',
#  'hers',
#  'smarts',
#  'brad',
#  'host',
#  'smith',
#  'left',
#  'barn',
#  'chaps',
#  'poss',
#  'tick',
#  'shacks',
#  'nu',
#  'champ',
#  'jbs',
#  'ty',
#  'jet',
#  'tes',
#  'post',
#  'flasks',
#  'bud',
#  'art',
#  'mull',
#  'charm',
#  'straw',
#  'grant',
#  'child',
#  'regs',
#  'meg',
#  'what',
#  'pinch',
#  'nsu',
#  'rock',
#  'plank',
#  'mudd',
#  'rhs',
#  'pills',
#  'shvitz',
#  'sans',
#  'plug',
#  'tip',
#  'law',
#  'get',
#  'am',
#  'marc',
#  'tad',
#  'troth',
#  'fright',
#  'lynd',
#  'hip',
#  'lamp',
#  'cult',
#  'find',
#  'shaq',
#  'fist',
#  'lott',
#  'ships',
#  'whigs',
#  'arch',
#  'slew',
#  'hall',
#  'blasts',
#  'hap',
#  'gods',
#  'brands',
#  'spark',
#  'jo',
#  'tjx',
#  'bad',
#  'pg',
#  'glands',
#  'bcs',
#  'brunch',
#  'blight',
#  'wards',
#  'pm',
#  'craft',
#  'lung',
#  'zach',
#  'hd',
#  'craps',
#  'star',
#  'whig',
#  'web',
#  'ho',
#  'chefs',
#  'drinks',
#  'vp',
#  'folk',
#  'horn',
#  'hull',
#  'chart',
#  'fifth',
#  'britt',
#  'skim',
#  'wsjt',
#  'kcnc',
#  'towns',
#  'kinds',
#  'punts',
#  'dips',
#  'wang',
#  'nash',
#  'bats',
#  'snag',
#  'slosh',
#  'bangs',
#  'watts',
#  'bbc',
#  'nytns',
#  'bursts',
#  'owns',
#  'sold',
#  'roc',
#  'pact',
#  'blacks',
#  'crabs',
#  'wrest',
#  'olds',
#  'suggs',
#  'grow',
#  'mock',
#  'bed',
#  'pnc',
#  'bands',
#  'truck',
#  'fronts',
#  'ark',
#  'thanks',
#  'bibb',
#  'gowns',
#  'z',
#  'war',
#  'gramps',
#  'rents',
#  'laps',
#  'clerk',
#  'khadr',
#  'pros',
#  'bends',
#  'pews',
#  'shrank',
#  'hips',
#  'goff',
#  'bc',
#  'om',
#  'drag',
#  'tri',
#  'clips',
#  'twin',
#  'when',
#  'lx',
#  'y',
#  'rips',
#  'jews',
#  'kuhl',
#  'fb',
#  'sept',
#  'rants',
#  'ky',
#  'stink',
#  'khmer',
#  'rb',
#  'lambs',
#  'which',
#  'club',
#  'crack',
#  'tv',
#  'rent',
#  'grasp',
#  'oct',
#  'cell',
#  'to',
#  'ha',
#  'of',
#  'strolls',
#  'fritz',
#  'harm',
#  'plants',
#  'shod',
#  'kraft',
#  'van',
#  'vows',
#  'harp',
#  'fill',
#  'act',
#  'splash',
#  'ok',
#  'sight',
#  'parks',
#  'tlc',
#  'kill',
#  'months',
#  'cart',
#  'steph',
#  'nets',
#  'frank',
#  'plant',
#  'stress',
#  'now',
#  'ind',
#  'slump',
#  'got',
#  'ping',
#  'welch',
#  'naps',
#  'sam',
#  'as',
#  'blond',
#  'must',
#  'bach',
#  'sights',
#  'chicks',
#  'tall',
#  'drums',
#  'jill',
#  'jeb',
#  'on',
#  'plans',
#  'rank',
#  'cracks',
#  'qb',
#  'told',
#  'tubs',
#  'neck',
#  'sturm',
#  'strength',
#  'trump',
#  'rex',
#  'froth',
#  'pads',
#  'blam',
#  'lands',
#  'birds',
#  'straps',
#  'studs',
#  'desk',
#  'kin',
#  'psych',
#  'longs',
#  'stan',
#  'gusts',
#  'norms',
#  'corn',
#  'kong',
#  'rahm',
#  'clerks',
#  'wink',
#  'shops',
#  'dust',
#  'curl',
#  'row',
#  'porth',
#  'bath',
#  'bent',
#  'trent',
#  'plus',
#  'burn',
#  'shift',
#  'xm',
#  'cnbc',
#  'town',
#  'gps',
#  'grew',
#  'phd',
#  'dump',
#  'stat',
#  'charts',
#  'bongs',
#  'staff',
#  'maps',
#  'fur',
#  'blow',
#  'tk',
#  'sharp',
#  'da',
#  'bel',
#  'rw',
#  'chad',
#  'be',
#  'bits',
#  'tells',
#  'ghosts',
#  'klis',
#  'span',
#  'meth',
#  'brent',
#  'shrinks',
#  'doll',
#  'mild',
#  'senn',
#  'mpc',
#  'usf',
#  'pan',
#  'thrills',
#  'tight',
#  'raw',
#  'dock',
#  'but',
#  'ny',
#  'wraps',
#  'so',
#  'del',
#  'jed',
#  'fills',
#  'cut',
#  'tufts',
#  'mdc',
#  'sank',
#  'check',
#  'fresh',
#  'syd',
#  'kpmg',
#  'rob',
#  'slabs',
#  'jew',
#  'peck',
#  'fit',
#  'slim',
#  'camps',
#  'cars',
#  'pam',
#  'blew',
#  'bump',
#  'fcc',
#  'nix',
#  'wright',
#  'helps',
#  'puff',
#  'lungs',
#  'francs',
#  'hen',
#  'snell',
#  'call',
#  'cum',
#  'sparks',
#  'kills',
#  'ball',
#  'crux',
#  'such',
#  'rhythm',
#  'fond',
#  'church',
#  'bonds',
#  'ma',
#  'bbdo',
#  'tic',
#  'shorts',
#  'grill',
#  'dawgs',
#  'sapp',
#  'dpp',
#  'folks',
#  'san',
#  'might',
#  'stuck',
#  'swiss',
#  'hawk',
#  'cub',
#  'send',
#  'trumps',
#  'snug',
#  'fast',
#  'dawn',
#  'stand',
#  'carts',
#  'butts',
#  'ws',
#  'the',
#  'stalk',
#  'clings',
#  'knock',
#  'dig',
#  'mccall',
#  'cd',
#  'rusk',
#  'cling',
#  'lt',
#  'blunt',
#  'cells',
#  'clip',
#  'fads',
#  'slots',
#  'trig',
#  'gross',
#  'marks',
#  'sends',
#  'wars',
#  'begs',
#  'trepp',
#  'odds',
#  'monks',
#  'fe',
#  'holtz',
#  'buff',
#  'black',
#  'fists',
#  'atsc',
#  'sprint',
#  'des',
#  'bowl',
#  'pull',
#  'warns',
#  'cbs',
#  'leg',
#  'list',
#  'gag',
#  'strip',
#  'nang',
#  'shed',
#  'winn',
#  'spun',
#  'lax',
#  'rhythms',
#  'wigs',
#  'betts',
#  'crest',
#  'mills',
#  'menk',
#  'blob',
#  'bmw',
#  'flings',
#  'locks',
#  'bask',
#  'talk',
#  'per',
#  'hut',
#  'bets',
#  'lens',
#  'wasl',
#  'ekg',
#  'limb',
#  'han',
#  'mas',
#  'lofts',
#  'film',
#  'thrall',
#  'rv',
#  'bolt',
#  'ben',
#  'crowd',
#  'hat',
#  'flank',
#  'pew',
#  'heck',
#  'capt',
#  'log',
#  'crab',
#  'still',
#  'thrown',
#  'hurts',
#  'thumb',
#  'sting',
#  'drift',
#  'high',
#  'slights',
#  'test',
#  'pad',
#  'id',
#  'blind',
#  'mar',
#  'wald',
#  'las',
#  'pink',
#  'hint',
#  'goths',
#  'shaft',
#  'porl',
#  'suv',
#  'swabs',
#  'cloth',
#  'fdr',
#  'pings',
#  'at',
#  'cows',
#  'te',
#  'wuss',
#  'lel',
#  'gloss',
#  'sew',
#  'hess',
#  'skills',
#  'brick',
#  'hub',
#  'gen',
#  'low',
#  'hmc',
#  'grows',
#  'wins',
#  'crust',
#  'shrug',
#  'shots',
#  'hot',
#  'raft',
#  'is',
#  'walks',
#  'lynch',
#  'plush',
#  'korn',
#  'skins',
#  'silk',
#  'banks',
#  'debs',
#  'mass',
#  'trench',
#  'cam',
#  'dunn',
#  'dot',
#  'johns',
#  'spends',
#  'son',
#  'stack',
#  'marsh',
#  'nov',
#  'pot',
#  'pol',
#  'tripp',
#  'blah',
#  'hard',
#  'milk',
#  'perch',
#  'whisk',
#  'licks',
#  'dress',
#  'lang',
#  'ap',
#  'not',
#  'swaths',
#  'pit',
#  'girls',
#  'strict',
#  'rib',
#  'led',
#  'pej',
#  'flop',
#  'phil',
#  'sow',
#  'toss',
#  'gwen',
#  'eggs',
#  'skiff',
#  'knelt',
#  'ran',
#  'sly',
#  'trips',
#  'plo',
#  'ca',
#  'smug',
#  'bros',
#  'snow',
#  'kids',
#  'sacks',
#  'dec',
#  'bang',
#  'plight',
#  'sec',
#  'ot',
#  'bush',
#  'gut',
#  'emts',
#  'brand',
#  'ebb',
#  'nuts',
#  'wells',
#  'truth',
#  'frocks',
#  'crp',
#  'sls',
#  'beth',
#  'fcat',
#  'weld',
#  'carr',
#  'mont',
#  'slum',
#  'propst',
#  'gal',
#  'scratch',
#  'tanks',
#  'dam',
#  'fda',
#  'plump',
#  'much',
#  'sling',
#  'grit',
#  'shack',
#  'blend',
#  'ninth',
#  'hong',
#  'cramps',
#  'mat',
#  'lamps',
#  'snarls',
#  'dnc',
#  'jinks',
#  'whiff',
#  'a',
#  'jos',
#  'glen',
#  'digs',
#  'drunk',
#  'pat',
#  'marx',
#  'mall',
#  'wax',
#  'want',
#  'bumps',
#  'sims',
#  'bet',
#  'buck',
#  'cents',
#  'schnapps',
#  'mows',
#  'bucs',
#  'third',
#  'math',
#  'puts',
#  'angst',
#  'sox',
#  'for',
#  'clown',
#  'ldl',
#  'riff',
#  'calls',
#  'traps',
#  'swap',
#  'chef',
#  'mess',
#  'molds',
#  'ends',
#  'brows',
#  'drawn',
#  'punt',
#  'c',
#  'punk',
#  'rod',
#  'spring',
#  'warms',
#  'dirt',
#  'bills',
#  'rush',
#  'kempt',
#  'twang',
#  'birt',
#  'ch',
#  'hills',
#  'mawr',
#  'snorts',
#  'mls',
#  'links',
#  'schupp',
#  'sir',
#  'lest',
#  'schatz',
#  'bluff',
#  'luc',
#  'bows',
#  'kent',
#  'hawks',
#  'lent',
#  'gang',
#  'two',
#  'fund',
#  'und',
#  'stir',
#  'laws',
#  'stamp',
#  'knicks',
#  'slurs',
#  'hugh',
#  'struck',
#  'el',
#  'trend',
#  'snap',
#  'oh',
#  'stern',
#  'tub',
#  'falls',
#  'qbs',
#  'brown',
#  'bids',
#  'kung',
#  'guns',
#  'temp',
#  'dip',
#  'terps',
#  'bram',
#  'minds',
#  'fsu',
#  'dwight',
#  'king',
#  'chic',
#  'blyth',
#  'notch',
#  'gas',
#  'we',
#  'kit',
#  'baths',
#  'chimps',
#  'wish',
#  'shirts',
#  'rid',
#  'le',
#  'cash',
#  'grin',
#  'rest',
#  'f',
#  'ship',
#  'atk',
#  'slow',
#  'hugs',
#  'dwells',
#  'tedd',
#  'drum',
#  'rash',
#  'stunts',
#  'pimps',
#  'tamp',
#  'bald',
#  'trish',
#  'cow',
#  'schultz',
#  'naz',
#  'o',
#  'dhl',
#  'vet',
#  'afl',
#  'park',
#  'belts',
#  'kiss',
#  'mrs',
#  'rift',
#  'spurt',
#  'lab',
#  'smash',
#  'by',
#  'in',
#  'drills',
#  'nast',
#  'herm',
#  'swung',
#  'ramp',
#  'gmac',
#  'shy',
#  'milks',
#  'terms',
#  'hunt',
#  'scheck',
#  'il',
#  'mob',
#  'sprang',
#  'right',
#  'bloc',
#  'texts',
#  'tend',
#  'lost',
#  'xp',
#  'his',
#  'coq',
#  'clock',
#  'wall',
#  'con',
#  'torn',
#  'show',
#  'news',
#  'thirst',
#  'sex',
#  'dwell',
#  'clump',
#  'kos',
#  'golf',
#  'hats',
#  'russ',
#  'vents',
#  ...]

# %% [markdown]
# #### 4. Compute ngrams
#
# a. Find the 10 most common bigrams
# b. Find the 10 most common trigrams

# %%
text_list
# Out:
# ['kbr',
#  'said',
#  'friday',
#  'the',
#  'global',
#  'economic',
#  'downturn',
#  'so',
#  'far',
#  'has',
#  'had',
#  'little',
#  'effect',
#  'on',
#  'its',
#  'business',
#  'but',
#  'warned',
#  'some',
#  'projects',
#  'on',
#  'its',
#  'books',
#  'could',
#  'be',
#  'in',
#  'jeopardy',
#  'if',
#  'the',
#  'headwinds',
#  'persist',
#  'into',
#  'next',
#  'year',
#  'with',
#  'the',
#  'economic',
#  'outlook',
#  'remaining',
#  'uncertain',
#  'it',
#  'is',
#  'possible',
#  'that',
#  'customers',
#  'may',
#  'cancel',
#  'or',
#  'delay',
#  'projects',
#  'that',
#  'are',
#  'under',
#  'way',
#  'said',
#  'william',
#  'utt',
#  'chief',
#  'executive',
#  'of',
#  'the',
#  'houston-based',
#  'engineering',
#  'and',
#  'construction',
#  'giant',
#  'and',
#  'government',
#  'contractor',
#  'he',
#  'did',
#  'not',
#  'predict',
#  'how',
#  'much',
#  'of',
#  'the',
#  "company's",
#  '15.3billion',
#  'in',
#  'future',
#  'business',
#  'commitments',
#  'could',
#  'be',
#  'affected',
#  'but',
#  'downplayed',
#  'the',
#  'potential',
#  'of',
#  'any',
#  'significant',
#  'impact',
#  'as',
#  'limited',
#  'the',
#  'remarks',
#  'came',
#  'during',
#  'a',
#  'conference',
#  'call',
#  'to',
#  'discuss',
#  "kbr's",
#  'third-quarter',
#  'financial',
#  'results',
#  'which',
#  'showed',
#  'a',
#  '35percent',
#  'improvement',
#  'over',
#  'the',
#  'same',
#  'period',
#  'in',
#  '2007',
#  'kbr',
#  'which',
#  'was',
#  'spun',
#  'off',
#  'from',
#  'halliburton',
#  'co',
#  'last',
#  'year',
#  'posted',
#  'better',
#  'numbers',
#  'and',
#  'beat',
#  'analyst',
#  'expectations',
#  'after',
#  'a',
#  'new',
#  'acquisition',
#  'helped',
#  'boost',
#  'sales',
#  'and',
#  'offset',
#  'losses',
#  'because',
#  'of',
#  'hurricane',
#  'ike',
#  'net',
#  'income',
#  'rose',
#  'to',
#  '85million',
#  'or',
#  '51',
#  'cents',
#  'per',
#  'share',
#  'from',
#  '63',
#  'million',
#  'or',
#  '37',
#  'cents',
#  'in',
#  'the',
#  'july-september',
#  'period',
#  'of',
#  '2007',
#  'income',
#  'from',
#  'continuing',
#  'operations',
#  'totaled',
#  '44',
#  'cents',
#  'per',
#  'share',
#  'including',
#  'hurricane',
#  'ike-related',
#  'costs',
#  'of',
#  '4',
#  'to',
#  '5',
#  'cents',
#  'a',
#  'share',
#  'revenue',
#  'climbed',
#  '39',
#  'percent',
#  'to',
#  '3.02',
#  'billion',
#  'from',
#  '2.18',
#  'billion',
#  'on',
#  'the',
#  'back',
#  'of',
#  'big',
#  'gains',
#  'in',
#  'the',
#  "company's",
#  'government',
#  'and',
#  'infrastructure',
#  'unit',
#  'and',
#  'services',
#  'division',
#  'investors',
#  'liked',
#  'what',
#  'they',
#  'saw',
#  'boosting',
#  'kbr',
#  'shares',
#  '77',
#  'cents',
#  'to',
#  '14.84',
#  'in',
#  'new',
#  'york',
#  'stock',
#  'exchange',
#  'trading',
#  'in',
#  'commenting',
#  'on',
#  'third-quarter',
#  'earnings',
#  'in',
#  'recent',
#  'days',
#  'oil',
#  'and',
#  'gas',
#  'executives',
#  'have',
#  'made',
#  'clear',
#  'that',
#  'the',
#  'industry',
#  'is',
#  'entering',
#  'a',
#  'more',
#  'challenging',
#  'era',
#  'given',
#  'the',
#  'extreme',
#  'volatility',
#  'in',
#  'the',
#  'credit',
#  'financial',
#  'and',
#  'commodity',
#  'markets',
#  'they',
#  'have',
#  'cut',
#  'capital',
#  'spending',
#  'budgets',
#  'for',
#  'exploration',
#  'next',
#  'year',
#  'revisited',
#  'generous',
#  'stock',
#  'buyback',
#  'programs',
#  'and',
#  'tried',
#  'to',
#  'reassure',
#  'investors',
#  'that',
#  'their',
#  'balance',
#  'sheets',
#  'are',
#  'strong',
#  'enough',
#  'to',
#  'endure',
#  'the',
#  'current',
#  'credit',
#  'crisis',
#  'utt',
#  'like',
#  'the',
#  'others',
#  'said',
#  'the',
#  'long-term',
#  'fundamentals',
#  'of',
#  'the',
#  'industry',
#  'remain',
#  'strong',
#  'he',
#  'suggested',
#  'kbr',
#  'could',
#  'even',
#  'benefit',
#  'from',
#  'the',
#  'fall',
#  'of',
#  'oil',
#  'prices',
#  'into',
#  'a',
#  'more',
#  'sustainable',
#  'range',
#  'which',
#  'has',
#  'helped',
#  'lower',
#  'the',
#  'costs',
#  'of',
#  'raw',
#  'materials',
#  'and',
#  'other',
#  'project',
#  'costs',
#  'that',
#  'could',
#  'encourage',
#  'customers',
#  'to',
#  'place',
#  'more',
#  'orders',
#  'just',
#  'based',
#  'on',
#  'the',
#  'change',
#  'in',
#  'oil',
#  'price',
#  'only',
#  'we',
#  'still',
#  'are',
#  'at',
#  'a',
#  'point',
#  'where',
#  'our',
#  'customers',
#  'are',
#  'making',
#  'an',
#  'affirmative',
#  'investment',
#  'decision',
#  'for',
#  'projects',
#  'utt',
#  'said',
#  'explaining',
#  'that',
#  'crude',
#  'prices',
#  'near',
#  '150',
#  'this',
#  'summer',
#  'likely',
#  'spurred',
#  'customers',
#  'to',
#  'delay',
#  'investments',
#  'until',
#  'prices',
#  'cooled',
#  'jeff',
#  'tillery',
#  'an',
#  'industry',
#  'analyst',
#  'with',
#  'tudor',
#  'pickering',
#  'holt',
#  'amp;amp',
#  'co',
#  'securities',
#  'in',
#  'houston',
#  'said',
#  'if',
#  'kbr',
#  'sees',
#  'projects',
#  'canceled',
#  'or',
#  'delayed',
#  'it',
#  'would',
#  'be',
#  'those',
#  'in',
#  'early',
#  'engineering',
#  'stages',
#  'where',
#  'final',
#  'investment',
#  'decisions',
#  "haven't",
#  'been',
#  'made',
#  'the',
#  'cost',
#  'structure',
#  'has',
#  'changed',
#  'so',
#  'much',
#  'that',
#  'a',
#  'number',
#  'of',
#  'these',
#  'projects',
#  'the',
#  'customer',
#  'is',
#  'just',
#  'going',
#  'to',
#  'have',
#  'to',
#  'go',
#  'back',
#  'and',
#  're-evaluate',
#  'he',
#  'said',
#  'but',
#  'he',
#  'doubts',
#  'big',
#  'projects',
#  'have',
#  'much',
#  'risk',
#  'because',
#  "there's",
#  'already',
#  'so',
#  'much',
#  'capital',
#  "that's",
#  'already',
#  'been',
#  'put',
#  'into',
#  'them',
#  "kbr's",
#  'biggest',
#  'business',
#  'is',
#  'designing',
#  'and',
#  'building',
#  'large-scale',
#  'oil',
#  'and',
#  'gas',
#  'projects',
#  'including',
#  'refineries',
#  'offshore',
#  'platforms',
#  'and',
#  'liquefied',
#  'natural',
#  'gas',
#  'terminals',
#  'it',
#  'also',
#  'takes',
#  'major',
#  'infrastructure',
#  'projects',
#  'in',
#  'the',
#  'u.s',
#  'and',
#  'abroad',
#  'from',
#  'repairing',
#  'airfields',
#  'in',
#  'iraq',
#  'to',
#  'building',
#  'embassies',
#  'in',
#  'other',
#  'countries',
#  'but',
#  'it',
#  'receives',
#  'more',
#  'attention',
#  'for',
#  'its',
#  'exclusive',
#  'multibillion-dollar',
#  'contract',
#  'with',
#  'the',
#  'pentagon',
#  'to',
#  'provide',
#  'non-military',
#  'support',
#  'to',
#  'the',
#  'u.s',
#  'army',
#  'in',
#  'the',
#  'middle',
#  'east',
#  'beginning',
#  'next',
#  'year',
#  'however',
#  'the',
#  'work',
#  'will',
#  'be',
#  'spread',
#  'among',
#  'several',
#  'contractors',
#  'and',
#  'kbr',
#  'expects',
#  'to',
#  'receive',
#  'roughly',
#  '40',
#  'percent',
#  'of',
#  'the',
#  'work',
#  'under',
#  'the',
#  'new',
#  'contract',
#  'utt',
#  'said',
#  'if',
#  'the',
#  'new',
#  'u.s',
#  'president',
#  'decides',
#  'to',
#  'pull',
#  'out',
#  'of',
#  'iraq',
#  'sooner',
#  'than',
#  'expected',
#  'kbr',
#  'could',
#  'see',
#  'a',
#  'short-term',
#  'increase',
#  'in',
#  'work',
#  'to',
#  'mobilize',
#  'people',
#  'and',
#  'equipment',
#  'before',
#  'iraq',
#  'operations',
#  'wind',
#  'down',
#  'utt',
#  'said',
#  'as',
#  'part',
#  'of',
#  'a',
#  'broader',
#  'diversification',
#  'effort',
#  'since',
#  'leaving',
#  'halliburton',
#  'in',
#  'april',
#  '2007',
#  'kbr',
#  'has',
#  'been',
#  'trying',
#  'to',
#  'bulk',
#  'up',
#  'other',
#  'divisions',
#  'including',
#  'its',
#  'domestic',
#  'construction',
#  'business',
#  'in',
#  'may',
#  'kbr',
#  'announced',
#  'a',
#  '550million',
#  'deal',
#  'to',
#  'buy',
#  'birmingham',
#  'ala.-based',
#  'engineering',
#  'and',
#  'construction',
#  'firm',
#  'be&amp;amp;k',
#  'that',
#  'deal',
#  'closed',
#  'in',
#  'july',
#  'and',
#  'in',
#  'the',
#  'third',
#  'quarter',
#  'helped',
#  'kbr',
#  'boost',
#  'revenues',
#  'by',
#  '600percent',
#  'at',
#  'its',
#  'services',
#  'unit',
#  'but',
#  'kbr',
#  'took',
#  'a',
#  'hit',
#  'of',
#  '4',
#  'to',
#  '5',
#  'cents',
#  'per',
#  'share',
#  'in',
#  'the',
#  'quarter',
#  'after',
#  'hurricane',
#  'ike',
#  'knocked',
#  'out',
#  'windows',
#  'and',
#  'damaged',
#  'the',
#  "company's",
#  'downtown',
#  'houston',
#  'office',
#  'building',
#  'resulting',
#  'in',
#  'lost',
#  'billable',
#  'work',
#  'hours',
#  'kbr',
#  'also',
#  'had',
#  'to',
#  'shell',
#  'out',
#  'for',
#  'repairs',
#  'to',
#  'operations',
#  'in',
#  'the',
#  'gulf',
#  'of',
#  'mexico',
#  'kbr',
#  'said',
#  'friday',
#  'the',
#  'global',
#  'economic',
#  'downturn',
#  'so',
#  'far',
#  'has',
#  'had',
#  'little',
#  'effect',
#  'on',
#  'its',
#  'business',
#  'but',
#  'warned',
#  'some',
#  'projects',
#  'on',
#  'its',
#  'books',
#  'could',
#  'be',
#  'in',
#  'jeopardy',
#  'if',
#  'the',
#  'headwinds',
#  'persist',
#  'into',
#  'next',
#  'year',
#  'with',
#  'the',
#  'economic',
#  'outlook',
#  'remaining',
#  'uncertain',
#  'it',
#  'is',
#  'possible',
#  'that',
#  'customers',
#  'may',
#  'cancel',
#  'or',
#  'delay',
#  'projects',
#  'that',
#  'are',
#  'under',
#  'way',
#  'said',
#  'william',
#  'utt',
#  'chief',
#  'executive',
#  'of',
#  'the',
#  'houston-based',
#  'engineering',
#  'and',
#  'construction',
#  'giant',
#  'and',
#  'government',
#  'contractor',
#  'he',
#  'did',
#  'not',
#  'predict',
#  'how',
#  'much',
#  'of',
#  'the',
#  "company's",
#  '15.3billion',
#  'in',
#  'future',
#  'business',
#  'commitments',
#  'could',
#  'be',
#  'affected',
#  'but',
#  'downplayed',
#  'the',
#  'potential',
#  'of',
#  'any',
#  'significant',
#  'impact',
#  'as',
#  'limited',
#  'the',
#  'remarks',
#  'came',
#  'during',
#  'a',
#  'conference',
#  'call',
#  'to',
#  'discuss',
#  "kbr's",
#  'third-quarter',
#  'financial',
#  'results',
#  'which',
#  'showed',
#  'a',
#  '35percent',
#  'improvement',
#  'over',
#  'the',
#  'same',
#  'period',
#  'in',
#  '2007',
#  'kbr',
#  'which',
#  'was',
#  'spun',
#  'off',
#  'from',
#  'halliburton',
#  'co',
#  'last',
#  'year',
#  'posted',
#  'better',
#  'numbers',
#  'and',
#  'beat',
#  'analyst',
#  'expectations',
#  'after',
#  'a',
#  'new',
#  'acquisition',
#  'helped',
#  'boost',
#  'sales',
#  'and',
#  'offset',
#  'losses',
#  'because',
#  'of',
#  'hurricane',
#  'ike',
#  'net',
#  'income',
#  'rose',
#  'to',
#  '85million',
#  'or',
#  '51',
#  'cents',
#  'per',
#  'share',
#  'from',
#  '63',
#  'million',
#  'or',
#  '37',
#  'cents',
#  'in',
#  'the',
#  'july-september',
#  'period',
#  'of',
#  '2007',
#  'income',
#  'from',
#  'continuing',
#  'operations',
#  'totaled',
#  '44',
#  'cents',
#  'per',
#  'share',
#  'including',
#  'hurricane',
#  'ike-related',
#  'costs',
#  'of',
#  '4',
#  'to',
#  '5',
#  'cents',
#  'a',
#  'share',
#  'revenue',
#  'climbed',
#  '39',
#  'percent',
#  'to',
#  '3.02',
#  'billion',
#  'from',
#  '2.18',
#  'billion',
#  'on',
#  'the',
#  'back',
#  'of',
#  'big',
#  'gains',
#  'in',
#  'the',
#  "company's",
#  'government',
#  'and',
#  'infrastructure',
#  'unit',
#  'and',
#  'services',
#  'division',
#  'investors',
#  'liked',
#  'what',
#  'they',
#  'saw',
#  'boosting',
#  'kbr',
#  'shares',
#  '77',
#  'cents',
#  'to',
#  '14.84',
#  'in',
#  'new',
#  'york',
#  'stock',
#  'exchange',
#  'trading',
#  'in',
#  'commenting',
#  'on',
#  'third-quarter',
#  'earnings',
#  'in',
#  'recent',
#  'days',
#  'oil',
#  'and',
#  'gas',
#  'executives',
#  'have',
#  'made',
#  'clear',
#  'that',
#  'the',
#  'industry',
#  'is',
#  'entering',
#  'a',
#  'more',
#  'challenging',
#  'era',
#  'given',
#  'the',
#  'extreme',
#  'volatility',
#  'in',
#  'the',
#  'credit',
#  'financial',
#  'and',
#  'commodity',
#  ...]

# %%
#a)
bigrams_dict = {}
for i in range(len(text_list)-1):
    bigram = tuple(text_list[i:i+2])
    if bigram in bigrams_dict:
        bigrams_dict[bigram] += 1
    else:
        bigrams_dict[bigram] = 1

# %%
bigrams_dict = {k: v for k, v in sorted(bigrams_dict.items(), key = lambda item: item[1], reverse=True)}

# %%
list(bigrams_dict.items())[0:10]
# Out:
# [(('of', 'the'), 3144),
#  (('in', 'the'), 2755),
#  (('to', 'the'), 1193),
#  (('on', 'the'), 1159),
#  (('for', 'the'), 942),
#  (('and', 'the'), 859),
#  (('in', 'a'), 841),
#  (('at', 'the'), 773),
#  (('to', 'be'), 741),
#  (('with', 'the'), 614)]

# %%
# b)
trigrams_dict = {}
for i in range(len(text_list)-1):
    trigram = tuple(text_list[i:i+3])
    if trigram in trigrams_dict:
        trigrams_dict[trigram] += 1
    else:
        trigrams_dict[trigram] = 1

trigrams_dict = {k: v for k, v in sorted(trigrams_dict.items(), key = lambda item: item[1], reverse=True)}

# %%
list(trigrams_dict.items())[0:10]
# Out:
# [(('one', 'of', 'the'), 229),
#  (('a', 'lot', 'of'), 199),
#  (('the', 'united', 'states'), 181),
#  (('going', 'to', 'be'), 93),
#  (('as', 'well', 'as'), 92),
#  (('can', 'be', 'reached'), 91),
#  (('the', 'end', 'of'), 91),
#  (('be', 'reached', 'at'), 90),
#  (('the', 'new', 'york'), 89),
#  (('to', 'be', 'a'), 85)]

# %% [markdown]
# #### 5. Make a Concordance
#
# a. Create a concordance display for an arbitrary word. See the example below
#
# ![](../../Data/figs/Sample-concordance-lines-of-actually.png)

# %%
# a)

def Concordance(text:str, keyword:str = "the") -> str:
    import string
    keyword = keyword.lower()
    text_lower = text.lower()
    text_list = text_lower.split()
    #text_list = [re.sub(r"[^a-z]", "", x) for x in text_list]# just for the sake of being consistent with not using re
    text_list = [w.strip(string.punctuation) for w in text_lower.split()]
    text_list = [x for x in text_list if x!=""]

    #concordance
    indices = [i for i, x in enumerate(text_list) if x == keyword]

    s="#\t\tPosition-5\t\tkeyword\t\tPosition+5\n"

    if len(indices)>10:
        for i in range(10):
            s+=f"{i+1}\t\t{' '.join(text_list[indices[i]-5:indices[i]])}\t\t{text_list[indices[i]]}\t{' '.join(text_list[indices[i]+1: indices[i]+6])}\n"
    else:
        for i in range(len(indices)):
            s+=f"{i+1}\t\t{' '.join(text_list[indices[i]-5:indices[i]])}\t\t{text_list[indices[i]]}\t{' '.join(text_list[indices[i]+1: indices[i]+6])}\n"
    print(s)
    return s

programming = Concordance(text, "programming")
# Out:
# #		Position-5		keyword		Position+5
# 1		the internet or cable television		programming	neither of which is subject
# 2		stations rely more on syndicated		programming	forget mj and bubba the
# 3		laid off almost all the		programming	and on-air staff at smooth
# 4		juicier bits lifted from network		programming	is everywhere on the web
# 5		only broadcast network airing regular		programming	on election night original episodes
# 6		khemlani the vice president for		programming	and development with an increasing
# 7		election night as a prime		programming	occasion the way the television
# 8		ban on russian cable television		programming	went into effect for ukrainians
# 9		commission has decided that other		programming	with similar language is not
# 10		sound as well as more		programming	choices moreover by abandoning analog

# %% [markdown]
# ***

# %% [markdown]
# ##### Extra Credit – Secret Message
# + The answers to the extra credit exercises will reveal a secret message.
# + We will be working with the following text file for these exercises:
# [Link to Text](https://web.stanford.edu/class/cs124/lec/secret_ec.txt)
# (No starter code in the Extra Credit)

# %% [markdown]
# ##### Extra Credit Exercise 1
# • Find the 2 most common words in secret_ec.txt containing the letter e.
# • Your answer will correspond to the first two words of the secret message.

# %%
secret = ""

with open(r"secret_ec.txt", "r") as f:
    secret_text = f.read()

# %%
# a)
text_lower = secret_text.lower()
text_list = set(text_lower.split())
text_list = [x for x in text_list if "e" in x]
freq_list = [text_lower.count(x) for x in text_list]

freq = {word:w_freq for word, w_freq in zip(text_list, freq_list)}

freq = {k: v for k, v in sorted(freq.items(), key = lambda item: item[1], reverse=True)}

# %%
freq
# Out:
# {'the': 32,
#  'best': 11,
#  'bubble': 8,
#  'are': 6,
#  'squeak': 5,
#  'heat': 5,
#  'like': 5,
#  'there': 4,
#  'face': 4,
#  'excellent': 3,
#  'theory': 3,
#  'object': 3,
#  'spade': 3,
#  'invent': 3,
#  'queen': 3,
#  'reign': 3,
#  'voice': 3,
#  'clover': 3,
#  'screeching': 3,
#  'they': 3,
#  'toe': 3,
#  'somber': 3,
#  'degree': 3,
#  'range': 3,
#  'tendency': 2,
#  'bee': 2,
#  'help': 2,
#  'defeated': 2,
#  'wicked': 2,
#  'dinner': 2,
#  'enjoy': 2,
#  'kneel': 2,
#  'tempt': 2,
#  'bare': 2,
#  'nervous': 2,
#  'hallowed': 2,
#  'sincere': 2,
#  'cave': 2,
#  'messy': 2,
#  'ahead': 2,
#  'bitter': 2,
#  'omniscient': 2,
#  'monkey': 2,
#  'abashed': 2,
#  'meat': 2,
#  'screw': 2,
#  'divergent': 1,
#  'purple': 1,
#  'offend': 1,
#  'overjoyed': 1,
#  'embarrassed': 1,
#  'laughable': 1,
#  'courageous': 1,
#  'elderly': 1,
#  'debonair': 1,
#  'toes': 1,
#  'mundane': 1,
#  'every': 1,
#  'flowery': 1,
#  'hesitant': 1}

# %%
secret+= " ".join(list(freq.keys())[:2])

# %%
secret
# Out:
# 'the best'

# %% [markdown]
# ##### Extra Credit Exercise 2
# • Find the 2 most common bigrams in secret_ec.txt where the second word in the bigram ends with a consonant.
# • Your answer will correspond to the next four words of the secret message.

# %%
text_lower = secret_text.lower()
text_list = text_lower.split()
bigrams = [text_list[i:i+2] for i in range(len(text_list)-1)]
bigrams = [x for x in bigrams if x[1][-1] not in "aeiou"]

bigrams_count= [bigrams.count(x) for x in bigrams]
bigrams= [" ".join(x) for x in bigrams]
bigrams_freq = {bi:bi_count for bi, bi_count in zip(bigrams, bigrams_count)}

bigrams_freq = {k: v for k, v in sorted(bigrams_freq.items(), key = lambda item: item[1], reverse=True)}

# %%
secret += " " + " ".join(list(bigrams_freq.keys())[:2])

# %%
secret
# Out:
# 'the best part about unix is'

# %% [markdown]
# ##### Extra Credit Exercise 3
# • Find all 5-letter-long words that only appear once in secret_ec.txt.
# • Concatenate your result. This will be the final word of the secret message.
#
# What is the secret message?

# %%
text_lower = secret_text.lower()
text_list = set(text_lower.split())
freq_list = [x for x in text_list if len(x)==5 and text_lower.count(x) == 1]

# %%
secret+= " "+ " ".join(freq_list)

# %%
print(secret)
# Out:
# the best part about unix is every thing
